# %%
import captions, task
import json, spacy
from itertools import accumulate
from spacy import displacy, Docs
nlp = spacy.load("en_core_web_sm")

# %%
stt_task = task.get_tasks()[0]
stt_json_path = f'{task.get_task_path(stt_task)}/{task.query(stt_task)[1]}'
stt = {}
with open(stt_json_path) as f_stt:
    stt = json.loads(f_stt.read())

# %%
[i['DisplayText'] for i in stt[:5]]
# Out:
# ['Much more thank you very much for joining us today.',
#  "That's good to be here. This is a broadcast first of course, the first interview with the serving chief of MI 6 and it wasn't that long ago that your name was classified let alone where you actually work that was also a state secret, so I suppose my first question has to be.",
#  'What are you doing here in a radio studio doing an interview?',
#  "Well, it's a good question, and the secret in the title of Secret Intelligence Service is going to remain. There are clearly. Some some things that II won't be able to discuss but over the last 10 years or so my predecessors have gradually tiptoed into into the light a bit and the reason they've done it and why I'm keen to.",
#  "Carry on with it and develop it a bit by coming on to the radio with you today is because I think it's important that people understand the role that we play in so far as we can talk about it in keeping people safe on the streets of the UK and in promoting our interests and values overseas now you also tweet."]

# %%
stt[1]['NBest'][0]['Words']
# Out:
# [{'Word': "that's", 'Offset': 33500000, 'Duration': 2700000},
#  {'Word': 'good', 'Offset': 36300000, 'Duration': 1400000},
#  {'Word': 'to', 'Offset': 37800000, 'Duration': 800000},
#  {'Word': 'be', 'Offset': 38700000, 'Duration': 1500000},
#  {'Word': 'here', 'Offset': 40300000, 'Duration': 2300000},
#  {'Word': 'this', 'Offset': 43900000, 'Duration': 2700000},
#  {'Word': 'is', 'Offset': 46700000, 'Duration': 1100000},
#  {'Word': 'a', 'Offset': 47900000, 'Duration': 2100000},
#  {'Word': 'broadcast', 'Offset': 50300000, 'Duration': 6200000},
#  {'Word': 'first', 'Offset': 56600000, 'Duration': 3000000},
#  {'Word': 'of', 'Offset': 59700000, 'Duration': 700000},
#  {'Word': 'course', 'Offset': 60500000, 'Duration': 2700000},
#  {'Word': 'the', 'Offset': 63300000, 'Duration': 800000},
#  {'Word': 'first', 'Offset': 64200000, 'Duration': 2100000},
#  {'Word': 'interview', 'Offset': 66400000, 'Duration': 2700000},
#  {'Word': 'with', 'Offset': 69200000, 'Duration': 1000000},
#  {'Word': 'the', 'Offset': 70300000, 'Duration': 900000},
#  {'Word': 'serving', 'Offset': 71300000, 'Duration': 5300000},
#  {'Word': 'chief', 'Offset': 76900000, 'Duration': 4700000},
#  {'Word': 'of', 'Offset': 81700000, 'Duration': 3500000},
#  {'Word': 'MI', 'Offset': 85500000, 'Duration': 4300000},
#  {'Word': 'six', 'Offset': 89900000, 'Duration': 4100000},
#  {'Word': 'and', 'Offset': 94100000, 'Duration': 800000},
#  {'Word': 'it', 'Offset': 95000000, 'Duration': 600000},
#  {'Word': "wasn't", 'Offset': 95700000, 'Duration': 2300000},
#  {'Word': 'that', 'Offset': 98100000, 'Duration': 900000},
#  {'Word': 'long', 'Offset': 99100000, 'Duration': 1100000},
#  {'Word': 'ago', 'Offset': 100300000, 'Duration': 5700000},
#  {'Word': 'that', 'Offset': 109800000, 'Duration': 3700000},
#  {'Word': 'your', 'Offset': 114000000, 'Duration': 3200000},
#  {'Word': 'name', 'Offset': 117300000, 'Duration': 5900000},
#  {'Word': 'was', 'Offset': 124400000, 'Duration': 3000000},
#  {'Word': 'classified', 'Offset': 127500000, 'Duration': 6200000},
#  {'Word': 'let', 'Offset': 134000000, 'Duration': 2000000},
#  {'Word': 'alone', 'Offset': 136100000, 'Duration': 3900000},
#  {'Word': 'where', 'Offset': 140100000, 'Duration': 2100000},
#  {'Word': 'you', 'Offset': 142300000, 'Duration': 1500000},
#  {'Word': 'actually', 'Offset': 143900000, 'Duration': 3300000},
#  {'Word': 'work', 'Offset': 147300000, 'Duration': 2600000},
#  {'Word': 'that', 'Offset': 150000000, 'Duration': 1100000},
#  {'Word': 'was', 'Offset': 151200000, 'Duration': 1000000},
#  {'Word': 'also', 'Offset': 152300000, 'Duration': 4700000},
#  {'Word': 'a', 'Offset': 161000000, 'Duration': 2800000},
#  {'Word': 'state', 'Offset': 163900000, 'Duration': 2700000},
#  {'Word': 'secret', 'Offset': 166700000, 'Duration': 3100000},
#  {'Word': 'so', 'Offset': 169900000, 'Duration': 1100000},
#  {'Word': 'i', 'Offset': 171100000, 'Duration': 700000},
#  {'Word': 'suppose', 'Offset': 171900000, 'Duration': 2700000},
#  {'Word': 'my', 'Offset': 174700000, 'Duration': 1100000},
#  {'Word': 'first', 'Offset': 175900000, 'Duration': 3100000},
#  {'Word': 'question', 'Offset': 179100000, 'Duration': 3300000},
#  {'Word': 'has', 'Offset': 182500000, 'Duration': 1600000},
#  {'Word': 'to', 'Offset': 184200000, 'Duration': 1200000},
#  {'Word': 'be', 'Offset': 185500000, 'Duration': 4100000}]

# %%
def get_word_at_charidx(words: list[dict], charidx: str) -> str:
    cum_lens = [0] + list(accumulate([len(word['Word']) + 1 for word in words[:-1]] + [len(words[-1])]))
    word = [word for idx, word in enumerate(words) if cum_lens[idx] <= charidx < cum_lens[idx+1]]
    return word

# %%
def get_sentences_with_offsets(stt: dict):
    docs_words = [(nlp(d['DisplayText']), d['NBest'][0]['Words'] if 'Words' in d['NBest'][0] else []) for d in stt]
    sents_words = [(s, dw[1]) for dw in docs_words for s in list(dw[0].sents)]
    return [[(t, get_word_at_charidx(sw[1], t.idx)) for t in sw[0]] for sw in sents_words]

# %%
sents = get_sentences_with_offsets(stt)

# %%
def sent_to_frags(sents: list):
    for s in sents:
        frag = []
        for idx, (token, offset) in enumerate(s):
            frag.append((token, offset))
            split = False
            if token.dep_ is 'punct':
                split = True
            elif idx != len(s) - 1 and s[idx+1][0].pos_ in ['CCONJ', 'SCONJ']:
                split = True
            elif idx != len(s) - 1 and s[idx+1][0].pos_ in ['AUX', 'PART', 'PROPN', 'PRON'] and len(frag) > 6:
                split = True
            elif idx != len(s) - 1 and s[idx+1][0].pos_ in ['ADP'] and len(frag) > 10:
                split = True
            if token.dep_ is 'det' or token.pos_ is 'DET':
                split = False
            if split:
                yield frag
                frag = []
        if len(frag):
            yield frag

# %%
def frags_to_clauses(frags: list):
    MIN_LEN = 5
    MAX_LEN = 16
    completed_loop = False
    while not completed_loop:
        for idx, f in enumerate(frags):
            completed_loop = idx == len(frags) - 1
            if len(frags[idx]) < MIN_LEN:
                frag_text = [t.text for (t,o) in frags[idx]]
                frag_len = len(frags[idx])
                punct_in_prev = any([t.dep_ is 'punct' for (t,o) in frags[idx-1]]) if idx > 0 else True
                frag_len_prev = len(frags[idx-1][0]) if idx > 0 else MAX_LEN + 1
                frag_len_next = len(frags[idx+1][0]) if idx < len(frags) -1 else MAX_LEN + 1
                prev_available = idx > 0 and (frag_len_prev + frag_len <= MAX_LEN) and not punct_in_prev
                next_available = frag_len + frag_len_next <= MAX_LEN and '.' not in frag_text
                if idx is 0 and frags[idx][-1][0].dep_ is 'punct':
                    pass
                elif prev_available:
                    frags[idx-1] = frags[idx-1] + frags[idx]
                    del frags[idx]
                    break
                elif next_available:
                    frags[idx+1] = frags[idx] + frags[idx+1]
                    del frags[idx]
                    break  
    return frags

# %%
def clauses_to_captions(clauses: list):
    for c in clauses:
        caption_nlp = nlp([t for (t,o) in c])
        caption_text = caption_nlp.text
        caption_start = c[0][1]['Offset']
        caption_end = c[-1][1]['Offset'] + c[-1][1]['Duration']
        yield {
            'text': caption_text,
            'start': caption_start,
            'end': caption_end
        }

# %%
frags = list(sent_to_frags(sents))
[(idx, ' '.join([token.text for (token, offset) in f])) for idx, f in enumerate(frags)]
# Out:
# [(0, 'Much more thank you very much for joining'),
#  (1, 'us today .'),
#  (2, "That 's good to be here ."),
#  (3, 'This is a broadcast first of course ,'),
#  (4, 'the first interview with the serving chief of'),
#  (5, 'MI 6'),
#  (6, "and it was n't that long ago"),
#  (7, 'that your name was classified let alone'),
#  (8, 'where you actually work that was also a state secret ,'),
#  (9, 'so I suppose my first question has'),
#  (10, 'to be .'),
#  (11, 'What are you doing here in a radio studio doing an interview ?'),
#  (12, 'Well ,'),
#  (13, "it 's a good question ,"),
#  (14, 'and the secret in the title of'),
#  (15, 'Secret Intelligence Service is going to remain .'),
#  (16, 'There are clearly .'),
#  (17, "Some some things that II wo n't"),
#  (18, 'be able to discuss'),
#  (19, 'but over the last 10 years'),
#  (20,
#   'or so my predecessors have gradually tiptoed into into the light a bit'),
#  (21, "and the reason they 've done it"),
#  (22, 'and'),
#  (23, "why I 'm keen to ."),
#  (24, 'Carry on with it'),
#  (25, 'and develop it a bit by coming on to the radio'),
#  (26, 'with you today is'),
#  (27, "because I think it 's important"),
#  (28, 'that people understand the role that we play in so far'),
#  (29, 'as we can talk about it in keeping people safe on the streets'),
#  (30, 'of the UK'),
#  (31, 'and in promoting our interests'),
#  (32, 'and values overseas now you also tweet .'),
#  (33, 'Yeah ,'),
#  (34, 'in fact ,'),
#  (35, 'you are the first tweeting see'),
#  (36, 'if I can call you'),
#  (37, 'that you do that for what reason again .'),
#  (38, 'You want to be in on the field ,'),
#  (39, 'yeah'),
#  (40, 'look .'),
#  (41, "I think it 's it 's for all the same reasons II"),
#  (42, 'was on Twitter'),
#  (43, 'before I became chief'),
#  (44, 'and I use Twitter ,'),
#  (45, 'a lot'),
#  (46, "when I was an ambassador 's ambassador to"),
#  (47, 'Turkey .'),
#  (48, 'And I found it a great medium'),
#  (49, 'because you were able to engage with people .'),
#  (50, "It 's not just a broadcast medium ."),
#  (51, 'You have a chance for a bit of back'),
#  (52, 'and forth .'),
#  (53, 'I enjoy a bit of banter you get'),
#  (54, 'some you get some pretty toxic stuff .'),
#  (55, 'At one level'),
#  (56, 'and you get quite a lot of of humorous stop in'),
#  (57, 'Turkey ,'),
#  (58, 'they love conspiracy theories so .'),
#  (59, 'I just found it useful way of bashing back against'),
#  (60, 'some of that stuff ,'),
#  (61, 'and explaining Britain'),
#  (62, 'and in this context .'),
#  (63, 'Again ,'),
#  (64, 'I think it gives me a chance'),
#  (65, 'to engage with people on Twitter talk a bit about the service talk'),
#  (66, "about some of the things we 're trying"),
#  (67, 'to do to modernize the service .'),
#  (68, 'And so you know it was a bit of an experiment ,'),
#  (69, 'but so far ,'),
#  (70, 'so good I think .'),
#  (71, 'Judging by your turn I used to tweet in'),
#  (72, 'Turkish on occasions .'),
#  (73, 'I was quite impressive your Turkish Subs pretty pretty good better'),
#  (74, 'than mine anyway .'),
#  (75, 'So it is Alright .'),
#  (76, "It 's getting a bit rusty"),
#  (77, 'before we get on to the wider world'),
#  (78, 'and your views on it in your services activities .'),
#  (79, 'As far'),
#  (80, 'as you can discuss them .'),
#  (81, 'Of course ,'),
#  (82, 'let me just ask you about your background .'),
#  (83, 'You spend a bit of time in the diplomatic service ,'),
#  (84, 'you being an ambassador ,'),
#  (85, 'but you were originally an intelligence officer .'),
#  (86, 'You began your career with MI 6 ?'),
#  (87, 'How did you get into the business of espionage ?'),
#  (88, "I 'm absolutely professional intelligence officer ."),
#  (89, 'I really enjoyed my time working as an ambassador'),
#  (90, 'and then working in the Foreign Office'),
#  (91, "but I 've always been an intelligence officer ."),
#  (92, 'To the to the core of my soul'),
#  (93, 'and I think like many folks ,'),
#  (94, 'leaving University looking at careers .'),
#  (95, 'I was looking around .'),
#  (96, 'I was ,'),
#  (97, 'I did take an interest in journalism'),
#  (98, 'and completely'),
#  (99, 'and utterly failed .'),
#  (100, 'I think I applied to the BBC'),
#  (101, 'World Service'),
#  (102, 'and .'),
#  (103, 'Got rejected without an interview of any kind'),
#  (104, 'so one looks around .'),
#  (105, 'I kept on coming back to the fact'),
#  (106, 'that I wanted to do something overseas .'),
#  (107, 'I want to do something that would make a difference'),
#  (108,
#   'and I was approached so I sort of followed through the application process'),
#  (109, 'with with SS'),
#  (110, "and I 've never regretted it ."),
#  (111, "I 've loved every minute of the work"),
#  (112, "that I 've done so with the classic tap on the shoulder"),
#  (113, 'was it at University .'),
#  (114, 'It was at University .'),
#  (115, 'I will even'),
#  (116, 'though the gentleman has passed away .'),
#  (117, 'I will respect the confidence of the individual'),
#  (118, 'who did it .'),
#  (119, 'But yes ,'),
#  (120, 'it was very much the way that people read about .'),
#  (121, 'I think he suggested'),
#  (122, 'that I might be interested in .'),
#  (123, 'In a parallel career in the parallel field of foreign affair .'),
#  (124, 'I had no idea what he meant'),
#  (125, 'but then I was taking I was asked'),
#  (126, 'to turn up at some building'),
#  (127, 'or the ground building just off of the Mail'),
#  (128, 'and it all became revealed unto me'),
#  (129, 'what I might be getting into'),
#  (130, 'when you finally knew what you were signing up for absolutely'),
#  (131, 'and II did sign up for it .'),
#  (132, 'And'),
#  (133, 'and I had a brilliant time there is'),
#  (134, 'something about .'),
#  (135, 'Trying to work out who might be prepared'),
#  (136, 'to help us that kind of'),
#  (137, 'if you like a bit of the thrill of the Chase'),
#  (138, 'as you try'),
#  (139, 'and sort of find a way in'),
#  (140, 'which you can get alongside them'),
#  (141,
#   'and then the fascinating business of working with people developing relationship'),
#  (142, 'with them having to do .'),
#  (143, 'Some pretty wild things you know after dark on the streets'),
#  (144, 'of Islamabad .'),
#  (145, "You know it 's the adrenaline is rushing so"),
#  (146, "it 's a very fulfilling ."),
#  (147, 'Korea ,'),
#  (148, "an you know you 're doing ,"),
#  (149, 'it for a for a genuinely good purpose .'),
#  (150, 'You know you ,'),
#  (151, 'you know'),
#  (152, "that you 're trying to keep things make things just a bit safer ."),
#  (153, 'To ask you exactly what was you doing on the streets'),
#  (154, 'of his neighborhood after dark ,'),
#  (155, "so I wo n't"),
#  (156, "'cause I know you would n't tell"),
#  (157, "me I do n't know ,"),
#  (158, "but the service does n't recruit that way anymore ."),
#  (159, "Does it there 's a discrete tap on the shoulder ."),
#  (160, 'In fact ,'),
#  (161, 'you could even apply openly to join'),
#  (162, 'my sense ?'),
#  (163, "Is there 's an invitation on your website"),
#  (164, 'to do that ,'),
#  (165, 'and understand your recruiting for quite a scene'),
#  (166, 'and you roll .'),
#  (167, 'Externally for the first time I am so'),
#  (168, 'I mean ,'),
#  (169, "you 're right of course ."),
#  (170, 'We still take recommendations ,'),
#  (171, 'but clearly we cast on that much more broadly than'),
#  (172, 'Oxbridge .'),
#  (173, 'Colleges these days ,'),
#  (174, 'rightly ,'),
#  (175, 'so'),
#  (176, 'and we get people drawing drawing in from all around the UK'),
#  (177, 'from all kinds of backgrounds'),
#  (178, "and that 's"),
#  (179, 'as it should be .'),
#  (180, 'Yeah ,'),
#  (181, 'you apply online .'),
#  (182, 'These days'),
#  (183, 'and then we take some care to make sure'),
#  (184, 'that .'),
#  (185, 'Once you apply online you can do so safely'),
#  (186, 'and'),
#  (187, 'and we can then take the application process forward'),
#  (188, 'so'),
#  (189, 'that that works well in for the senior appointments .'),
#  (190, 'We quite often advertised'),
#  (191, 'and we will shortly be advertising for a role the role'),
#  (192, 'is to be our new Q In Fact .'),
#  (193, "So I 'm quite excited about that ,"),
#  (194, 'about the sort of person we might get'),
#  (195, 'to come'),
#  (196, "and join us II'm hoping that will get"),
#  (197, 'somebody who ?'),
#  (198,
#   'Probably has gotten industry background who really understands technology at a very deep level'),
#  (199, 'because we need their help .'),
#  (200, 'We are in an increasingly contested difficult world'),
#  (201, 'where technology is making what we do for a living more'),
#  (202, 'of a challenge .'),
#  (203, 'We have to therefore use'),
#  (204, 'and harness technology .'),
#  (205, 'And the only way we can do'),
#  (206, 'that .'),
#  (207, 'I think is with good leadership from'),
#  (208,
#   'somebody who can help us partner with the private sector affectively .'),
#  (209, 'So just for people who underwear Q'),
#  (210, 'Exists in James Bond films as the guy'),
#  (211, 'who makes all the gadgets you actually have a real life .'),
#  (212, 'Q'),
#  (213, 'We do in the in this one life imitates art .'),
#  (214, 'So we in fact ,'),
#  (215, 'a few years ago .'),
#  (216, 'We were looking to remodel our technical side of'),
#  (217, 'it .'),
#  (218, 'A lot of people would would identify the GC'),
#  (219, 'HQ rightly with being this amazing technology organization ,'),
#  (220, 'but my own organization ,'),
#  (221, 'we have a very large technical element to'),
#  (222, 'it ,'),
#  (223, 'and many of my colleagues are our technologists .'),
#  (224, 'We were reshaping it .'),
#  (225, 'A few years ago'),
#  (226, 'and we can think about the right name for'),
#  (227, 'it'),
#  (228, 'and in here we thought walk .'),
#  (229, "Come on let 's go for it"),
#  (230, 'and so ,'),
#  (231, 'so we decided to call it Q.'),
#  (232, 'So we have done ever since .'),
#  (233, 'And this will be the leader of that team ,'),
#  (234, 'so the original .'),
#  (235, 'Q was in Flemington Bond'),
#  (236, 'and you borrowed from him .'),
#  (237, "I 'm afraid today ."),
#  (238, "We 've gone the other way around ."),
#  (239, 'You know ,'),
#  (240, 'see is still see you know ,'),
#  (241, "we 've never gone too ."),
#  (242, 'It was your attention to doing so ,'),
#  (243, 'but yeah ,'),
#  (244, 'so'),
#  (245, 'and I hope that will obviously .'),
#  (246, 'It will excite a bit of interest'),
#  (247,
#   "because it 's it is absolutely critical as the modernization of the servers"),
#  (248, 'that we get this partnership around technology right in'),
#  (249, 'our traditional model .'),
#  (250, 'Tom has been'),
#  (251, 'if you like kind of boffins behind the wire .'),
#  (252, "We 've got fantastic people who Beaver away"),
#  (253, 'and do the most amazing work around .'),
#  (254, 'Developing technology for us ,'),
#  (255, 'but in the 21st century that model'),
#  (256, "does n't scale"),
#  (257, "and you ca n't stay ."),
#  (258, "You ca n't achieve the pace you need in order"),
#  (259, 'to stay ahead of your adversaries ,'),
#  (260, 'so the only way to do that'),
#  (261, 'is to be in the mix with technology companies big'),
#  (262, 'and small'),
#  (263, 'and that is going to take us into .'),
#  (264, 'I think some interesting'),
#  (265, 'and challenging new areas'),
#  (266, "and we 're going to have to"),
#  (267, 'be a little bit more open in terms of that partnering'),
#  (268, 'with with technology companies that we have'),
#  (269, 'been traditionally used to doing that there'),
#  (270, 'will be technology being developed .'),
#  (271, 'Today ,'),
#  (272, 'Tom'),
#  (273, 'where the people developing it .'),
#  (274, 'Will have no idea'),
#  (275, 'that there might be an application for'),
#  (276, 'their technology in my world'),
#  (277, 'and so you know ,'),
#  (278, 'I need to reach out to these people'),
#  (279, 'and in order to reach out to'),
#  (280, 'them .'),
#  (281, "I 'm going to be ."),
#  (282, 'You know ,'),
#  (283, "we 're going to be a little bit more open about"),
#  (284, 'who we are .'),
#  (285, "So I think let 's move on to"),
#  (286, 'your actual business end ,'),
#  (287, 'which is your foreign intelligence service .'),
#  (288, 'Domestic intelligence domestically is taken care of by the police ,'),
#  (289, 'etc'),
#  (290, 'and your business is international .'),
#  (291, 'The Integrative review ,'),
#  (292,
#   'which was the big Whitehall wide review of all government foreign policy'),
#  (293,
#   'and security policy published last month painted quite a scary view .'),
#  (294, 'Of the world a world'),
#  (295, "where international sureties ca n't be relied on"),
#  (296, 'any longer .'),
#  (297, 'International understandings'),
#  (298, "that we 've lived with comfortably maybe"),
#  (299, "since it 's so Cold War may"),
#  (300, 'be going to crumble do you share'),
#  (301, 'that slightly troubling worldview ?'),
#  (302, "I think it 's undoubtedly a highly contested"),
#  (303, 'and in many ways rather dangerous world ?'),
#  (304, 'And I think the integrated review captures'),
#  (305, 'that rather well .'),
#  (306, 'I mean ,'),
#  (307, 'the thing I like about it .'),
#  (308, "It 's not defeatist ,"),
#  (309, 'though it is .'),
#  (310, 'It is'),
#  (311, 'and I understand'),
#  (312, 'why you would use to describe it .'),
#  (313, 'In the terms you did ,'),
#  (314, 'but it also sets out a very clear vision of the role'),
#  (315, 'that the UK can play'),
#  (316, 'and of course ,'),
#  (317, "we 'll play our part in ."),
#  (318, 'In that'),
#  (319, 'because will help along with GC HQ'),
#  (320, 'and MI 5 to defend against those threats .'),
#  (321, 'Wherever they come from ,'),
#  (322, 'but also in our case as SAS one of'),
#  (323, 'our jobs .'),
#  (324, "If you 'd like us to provide a kind of assurance wrapper"),
#  (325, 'around some of the more positive forward looking stuff ,'),
#  (326, 'I mean ,'),
#  (327, 'if you wanna things ,'),
#  (328, 'which is central to ?'),
#  (329, 'The Integrative review'),
#  (330, 'as it is a sense of the UK as a science'),
#  (331, 'and technology power uh recognition .'),
#  (332, 'I think'),
#  (333, 'that in the 21st century .'),
#  (334, "If you 're going to succeed ,"),
#  (335, 'as a as a country as a nation'),
#  (336, "and you 're going to have to master certain key technologies"),
#  (337, "and certainly you 're going to have"),
#  (338, 'to be in a place'),
#  (339, 'where'),
#  (340, 'either you'),
#  (341, 'or trusted allies have access to those technologies .'),
#  (342, 'And'),
#  (343, 'that'),
#  (344, 'if you like please back into what'),
#  (345, 'I was just saying about Q. You know ,'),
#  (346, 'we have got to be absolutely the at the forefront of'),
#  (347, 'that he wants the one single biggest thing'),
#  (348, 'that keeps you awake at night .'),
#  (349, "Now I do n't in all honesty ."),
#  (350, 'I sleep well'),
#  (351, 'because'),
#  (352, "'cause There are always issues that one"),
#  (353, 'is concerned about so I think from'),
#  (354, 'my perspective .'),
#  (355, 'All of this is ,'),
#  (356, 'is manageable .'),
#  (357, 'As long'),
#  (358, 'as we keep doing what some of the stuff'),
#  (359, "that 's in integrated review says we"),
#  (360, 'should do .'),
#  (361, 'But mostly the reason ?'),
#  (362, "Why I do n't have sleepless nights in the spaces"),
#  (363, 'because the great advantage .'),
#  (364, 'We have over the authoritarian regimes is'),
#  (365, "they do n't have friends ."),
#  (366, 'Now we have friends ,'),
#  (367, 'we have allies .'),
#  (368, 'And I think you know ,'),
#  (369, "there 's been a bit of a reassertion of"),
#  (370, 'that over the last few months ,'),
#  (371, 'which I think is welcome here in'),
#  (372, 'London .'),
#  (373, "So I honestly do n't there are lots of things ."),
#  (374, 'Of course I fret about'),
#  (375, 'and I worry about ,'),
#  (376, 'but'),
#  (377, 'but overall ,'),
#  (378, 'I remain pretty positive about our agenda .'),
#  (379, 'Let me ask him a couple of specifics'),
#  (380, 'that were actually mentioned in the integrated review .'),
#  (381, 'One is the prospect of a CBR an attack'),
#  (382, 'and the review stated'),
#  (383, 'that a CRM ,'),
#  (384, 'which for people who may not know'),
#  (385, 'me as a chemical biological radiological'),
#  (386, 'or nuclear attack ,'),
#  (387, 'a dirty bomb .'),
#  (388, "I suppose in Layman 's terms ."),
#  (389, 'Being deliverable'),
#  (390, 'and being actually quite likely to have happened by 2030 ,'),
#  (391, 'is that sort of threat something you'),
#  (392, "'ve actively come across"),
#  (393, 'or your officers have come across elsewhere in the world .'),
#  (394, 'It would be stated in those terms .'),
#  (395, "If we had n't ."),
#  (396, 'I mean ,'),
#  (397, "there 's clear intent from these types of groups"),
#  (398, 'to do us ,'),
#  (399, 'the maximum amount of harm at the moment .'),
#  (400, 'We have been very successful'),
#  (401, 'if you like I mean ,'),
#  (402, 'one of the one of the truisms about intelligence work .'),
#  (403, 'Thomas'),
#  (404, 'that you ,'),
#  (405, 'you get to see our failures .'),
#  (406, "You do n't get to see our successes"),
#  (407, 'and that is particularly true in true in counterterrorism workwear .'),
#  (408, 'You know ,'),
#  (409, 'we worked really ,'),
#  (410, 'really hard to the point'),
#  (411, 'where awful ,'),
#  (412, "though these attacks are they 've involved pretty low ."),
#  (413, 'Tech use of vehicles'),
#  (414, 'or people acquiring knives'),
#  (415, 'and trying to do as much damage'),
#  (416, 'as they can ,'),
#  (417, 'but clearly there is there is a limit to'),
#  (418, 'what you can do ,'),
#  (419, 'particularly on brilliant police able to react as fast'),
#  (420, 'as they self evidently do .'),
#  (421, 'So these groups are perpetually looking for'),
#  (422, 'something which would'),
#  (423, 'either be what you know what is called in the traders'),
#  (424, 'you know spectacular a 9/11 type thing'),
#  (425, 'will find some new'),
#  (426, 'and innovative way of doing it'),
#  (427, "and they 're pretty they innovate they innovate"),
#  (428, 'and their use of social media'),
#  (429, 'and they innovate in trying to do'),
#  (430, 'us harm'),
#  (431, "so we 're very conscious of it ."),
#  (432, 'But we take we do a lot of work'),
#  (433, 'to get ahead of that by you know'),
#  (434, 'being able to understand .'),
#  (435, 'These groups'),
#  (436, 'and then disrupt them'),
#  (437, 'before they develop the sort of capability'),
#  (438, 'that could do a serious harm have'),
#  (439, 'you come across actual evidence of a real plot no matter ?'),
#  (440, 'How far down the line .'),
#  (441, 'It was obviously an attack directed to the UK'),
#  (442, "II'm not going to get into individual ."),
#  (443, 'Intelligence'),
#  (444, 'and what we may not may'),
#  (445, 'or may not have uncovered'),
#  (446, 'but I you know ,'),
#  (447, 'I will say'),
#  (448, 'if you like more generally at some'),
#  (449, 'that we have definitely picked up intent from group stock icon .'),
#  (450, 'Al Qaeda'),
#  (451, 'and isis in the past to try'),
#  (452, 'and find ways of being'),
#  (453, 'and get hold of this CV RN .'),
#  (454, 'Capability'),
#  (455, "and that 's"),
#  (456, "why it 's in there ,"),
#  (457, 'you know it reflects the fact'),
#  (458, "that we know they 're trying ."),
#  (459, 'But so far .'),
#  (460, "We 've managed to stop them from achieving"),
#  (461, 'that .'),
#  (462, "We 're not talking about ancient history here"),
#  (463, "we 're talking about active groups now still trying today ."),
#  (464, 'Are we ,'),
#  (465, "we 're certainly talking about groups ,"),
#  (466, 'which are you know actor .'),
#  (467, 'We all know'),
#  (468, 'that Al Qaeda'),
#  (469, 'and isis ,'),
#  (470, "although they 've been pretty damaged over the last few years"),
#  (471, 'are still there .'),
#  (472, 'You mentioned Irish'),
#  (473, 'or isis ,'),
#  (474, 'they go by many names ?'),
#  (475, 'They are on the rise again are'),
#  (476, "n't they ?"),
#  (477, 'They were compressive defeated militarily in Syria'),
#  (478, 'and Iraq ,'),
#  (479, 'but again another thing .'),
#  (480, 'The IR predicts is'),
#  (481, 'that there will be more failed states ,'),
#  (482, 'either in the Middle East'),
#  (483, 'or Africa'),
#  (484, 'and we know dash is on the rise in'),
#  (485, 'Africa .'),
#  (486, 'Across the continent in this AL West'),
#  (487, 'African also East Africa'),
#  (488, 'as we saw in Mozambique .'),
#  (489, 'Quite recently very alarming attack took over town'),
#  (490, 'and .'),
#  (491, 'Kill a lot of western workers there'),
#  (492, 'how likely is it at the moment'),
#  (493, 'and'),
#  (494,
#   'how close are we seeing another serious somewhere else another failed state that dash'),
#  (495, 'might be able take control of .'),
#  (496, 'Look at some you know ,'),
#  (497, "I wo n't downplay the seriousness of of of the situation ."),
#  (498, 'I mean ,'),
#  (499, 'one level .'),
#  (500, 'We have been really successful against isis ,'),
#  (501, 'and its main headquarters area in Iraq'),
#  (502, 'and Syria'),
#  (503, 'and that pressure remains on them .'),
#  (504, "I do n't think they 've recovered to"),
#  (505, 'anything'),
#  (506, 'like you have to think back to'),
#  (507, 'where they were ,'),
#  (508, 'and 2014 .'),
#  (509, "Holding swathes of territory they 're just"),
#  (510, 'not in that place'),
#  (511, 'but they are ,'),
#  (512, 'they are resilient .'),
#  (513, 'We do have to keep the pressure on on'),
#  (514, 'the'),
#  (515, 'and of course ,'),
#  (516, "we 've been doing that in Afghanistan against"),
#  (517, 'Al Qaeda pretty effectively for the last 20 years .'),
#  (518, 'So we need to find ways of keeping that pressure on'),
#  (519, 'them ,'),
#  (520, "but you 're right"),
#  (521, 'This is a very toxic .'),
#  (522, 'Creed'),
#  (523, 'but one which seems to be able'),
#  (524, 'to use modern social media really effectively'),
#  (525, 'to inspire parallel movements in different parts of the world'),
#  (526, "and what we 're seeing in Mozambique ?"),
#  (527, "Is is pretty disturbing is n't it"),
#  (528, 'and you can see'),
#  (529,
#   'where the local authorities are unable to exert appropriate control .'),
#  (530, 'Then the space opens up for these groups'),
#  (531, "and it 's part of my services job ."),
#  (532, 'Of course to try'),
#  (533, 'and go to those places shine a light on'),
#  (534, 'some of the stuff going on there'),
#  (535, 'and help to disrupt those groups .'),
#  (536, 'But we can only be part of a broader effort .'),
#  (537, 'I mean ,'),
#  (538, 'you got ta you got ta back'),
#  (539,
#   'that up with with work in the development space work in conflict prevention'),
#  (540, 'and'),
#  (541, 'and that is'),
#  (542, 'that you know the duty of of .'),
#  (543, 'Diplomats'),
#  (544, 'and others ,'),
#  (545, 'but'),
#  (546, 'but our role is to try'),
#  (547, 'and get in there'),
#  (548, 'and make life as difficult as possible for these groups'),
#  (549, 'and in particular disrupt any efforts by'),
#  (550, 'them to direct tax attacks against the United'),
#  (551, 'Kingdom ,'),
#  (552, 'well funny .'),
#  (553, 'You should mention'),
#  (554, 'that connections about Afghanistan .'),
#  (555, 'Of course ,'),
#  (556, 'right chief defense off Johnson .'),
#  (557, 'Carter has expressed his concern'),
#  (558, 'and disappointment .'),
#  (559, 'The US pullout militarily from Afghanistan by'),
#  (560, 'September ,'),
#  (561, '11th this year ,'),
#  (562, 'the 20th anniversary of the attacks on the twin towers .'),
#  (563, 'Do you also agree'),
#  (564, 'that not having a military presence in'),
#  (565,
#   'Afghanistan any longer makes it harder to disrupt terrorist attacks on the UK'),
#  (566, 'Homeland .'),
#  (567, "Look it 's going to force us"),
#  (568, 'to have to work very differently .'),
#  (569, 'You know ,'),
#  (570, 'we have had a certain model of working'),
#  (571, "as I 've just said"),
#  (572, "as you know it 's been pretty effective against"),
#  (573, 'Al Qaeda .'),
#  (574, "We 've been UK supported the peace process ,"),
#  (575, 'and'),
#  (576, 'and we continue to do that .'),
#  (577, 'The fact is the president has made'),
#  (578, 'his decision'),
#  (579, 'and we have to now work with'),
#  (580, 'that .'),
#  (581, "And so we 're doing a lot of work"),
#  (582, 'and thinking through'),
#  (583, "how we 're going to achieve the same mission ,"),
#  (584, "but I 'm very clear"),
#  (585, "that there 's been an awful lot of sacrifice clearly ."),
#  (586, "I think it 's 457 servicemen have lost"),
#  (587, 'their lives in the Afghan .'),
#  (588, 'Campaign'),
#  (589, 'so we owe it to them to make sure'),
#  (590, 'that we preserve some of the gains insecurity'),
#  (591, "that we 've achieved"),
#  (592, 'and we will find a way of doing'),
#  (593, 'that ,'),
#  (594, "we 're not going to go anywhere ."),
#  (595, 'We will we will find a way of working'),
#  (596, 'which is in a slightly different model clearly'),
#  (597, "when you do n't have the military on the ground alongside"),
#  (598, 'you'),
#  (599, 'but we will find away'),
#  (600, 'because .'),
#  (601, "Very clearly we ca n't allow Afghanistan"),
#  (602, 'to slide back to a situation that'),
#  (603, 'we saw in the run up to 9/11'),
#  (604, 'and'),
#  (605, 'that for me is one of those sort of very easy'),
#  (606, 'to state very difficult to execute commitments'),
#  (607, 'that we have no second 9/11 .'),
#  (608, 'So we need to make sure we work with the Americans'),
#  (609, 'and others too .'),
#  (610, "Ensure that does n't happen with your input into"),
#  (611, 'it your advice'),
#  (612, 'if your counterpart ,'),
#  (613, 'the director of the CIA for example ,'),
#  (614, 'to do just that to stay in'),
#  (615, 'Afghanistan .'),
#  (616, 'Military is'),
#  (617, 'that what you wanted to see happen ,'),
#  (618, "but I probably wo n't go into the sort of conversations ."),
#  (619, 'I would have as a director of'),
#  (620, 'CIA'),
#  (621, 'because otherwise I might not have very many of'),
#  (622, 'them so .'),
#  (623, 'Look we ,'),
#  (624, 'we work incredibly closely with our American partners'),
#  (625, 'and they are as focused'),
#  (626, 'as we are on trying to make sure'),
#  (627, "that that threat does n't re emerge from from"),
#  (628, 'Afghanistan'),
#  (629, 'so you know'),
#  (630, "that that 's what we 'll do"),
#  (631, "we 'll work together on it ,"),
#  (632, 'but the world is going to be ?'),
#  (633, "Let 's say"),
#  (634, 'because of the US pullout .'),
#  (635, "I think it 's it 's difficult"),
#  (636, 'to judge .'),
#  (637, 'We will have to see what happens ,'),
#  (638, 'but I think you know in my business .'),
#  (639, 'You know you ,'),
#  (640, 'you plan for the worst'),
#  (641, 'and so you work through the scenarios'),
#  (642, 'that you need to ,'),
#  (643, "but I 'm really clear"),
#  (644, "that there 's a job to be done continuing job"),
#  (645, 'to be done in Afghanistan'),
#  (646, 'and we will have to find a way'),
#  (647, 'to do it .'),
#  (648, "Let 's talk about Russia ."),
#  (649,
#   'There are currently 100 thousand Russian troops on the Ukraine border'),
#  (650, 'President Putin this week is also vowed'),
#  (651, 'to'),
#  (652, 'and I quote make his enemies sorry as never before'),
#  (653, 'if they crosses red lines do you believe an invasion ?'),
#  (654, 'Is imminent Russia into Ukraine was this'),
#  (655, 'is some form of Saber rattling ?'),
#  (656, 'Look ,'),
#  (657, "I do n't think it 's entirely clear"),
#  (658, "what is in Mr. Putin 's mind"),
#  (659, 'and it may be'),
#  (660, "that he 's not made up his mind yet quite"),
#  (661, 'what he wants to do ,'),
#  (662, "but clearly what they 've been doing around the borders of"),
#  (663, "Ukraine is deeply worrying 'cause"),
#  (664, 'as you rightly say Tom This is the biggest build up since .'),
#  (665, "the Cold War It 's larger than in 2014 ,"),
#  (666, 'when they ?'),
#  (667, 'Invaded'),
#  (668, 'and annexed Crimea'),
#  (669, 'so all we can do at this point'),
#  (670, 'is to signal really clearly to Moscow'),
#  (671, 'that'),
#  (672, 'if they you know'),
#  (673, 'where our own .'),
#  (674, 'It would be very clear in our messaging'),
#  (675, 'that he would pay a huge price'),
#  (676, 'if he did ,'),
#  (677, "and he 's still paying the Russian people"),
#  (678, 'are still suffering from the sanctions that'),
#  (679, 'Putin brought'),
#  (680, 'upon them in 2014 .'),
#  (681, 'So I hope'),
#  (682, 'that you know'),
#  (683, "that he 's not intending anything of that kind"),
#  (684, "but it 's ."),
#  (685, 'It is very worrying'),
#  (686, 'and the problem with the Russians'),
#  (687, "as we 've experienced here in Salisbury ,"),
#  (688, 'about which'),
#  (689, 'dice'),
#  (690, 'and I still get I still get angry in that sorry'),
#  (691, 'because I know .'),
#  (692, 'How near we came to very significant casualties'),
#  (693, 'you know'),
#  (694, 'if you imagine ?'),
#  (695, 'What would have happened'),
#  (696, 'if a kid come across that material'),
#  (697, 'and spread around'),
#  (698, 'and the family of .'),
#  (699, 'Dawn Sturgess of course ,'),
#  (700, 'you know ,'),
#  (701, "I 've had an awful tragedy visited"),
#  (702, 'upon them'),
#  (703, 'when'),
#  (704, 'when she was killed by it .'),
#  (705, 'So there is this sort of .'),
#  (706, 'There is this element of recklessness there in the way'),
#  (707, 'they go about things'),
#  (708, "and we 've just had this extraordinary story"),
#  (709, 'and in Czechoslovakia .'),
#  (710, 'I mean ,'),
#  (711, "it 's extraordinary"),
#  (712, "if you think about it 's the same groups ,"),
#  (713, 'the same group'),
#  (714, 'and Russian military intelligence Gru .'),
#  (715, 'Same 2 individuals who came to Salisbury involved in an attack'),
#  (716, 'on a factory ,'),
#  (717, 'which left 2 checks dead so .'),
#  (718, 'When you get that pattern of reckless behavior of course ,'),
#  (719, "you then look at what 's happening around"),
#  (720, 'Ukraine'),
#  (721, 'and'),
#  (722, 'and of course ,'),
#  (723, 'it gives us worries us'),
#  (724, "and it 's"),
#  (725, "why we 've coordinated so closely with"),
#  (726, "our allies to make sure we 're getting"),
#  (727, 'her messages back to President Putin'),
#  (728, 'and have those firm messages being passed .'),
#  (729, 'I mean ,'),
#  (730, 'you can make politicians can make speeches'),
#  (731, 'but it did .'),
#  (732, 'Are you communicating ?'),
#  (733, 'Over other channels to make sure'),
#  (734, 'that the message is received ,'),
#  (735, 'loud'),
#  (736, 'and clear'),
#  (737, 'that there will be some sort of recompense at the Russians'),
#  (738, 'are in absolutely no doubt of'),
#  (739, 'where the UK stands on this issue'),
#  (740, 'and there'),
#  (741,
#   'and absolutely no doubt aware the Biden administration stands on this issue'),
#  (742, 'because the channels are open .'),
#  (743, 'I mean ,'),
#  (744, 'they they told me I wonder who'),
#  (745, "'s actually picked up the phone ."),
#  (746, 'Have you I have not picked up the phone'),
#  (747, 'but'),
#  (748, 'but I you know I have ways of communicating'),
#  (749, 'what ?'),
#  (750, 'What I need to do .'),
#  (751, 'But there are plenty of other channels'),
#  (752, 'and we sit next to them in the UN'),
#  (753, 'Security Council as permanent permanent members'),
#  (754, 'and we are able to communicate with'),
#  (755, 'them .'),
#  (756, "It 's not you know ,"),
#  (757, 'we ,'),
#  (758, 'we want to this is not .'),
#  (759, 'At the end of the day ,'),
#  (760, 'the the sort of relationship .'),
#  (761, 'We want to have with the Russians .'),
#  (762, "It 's really it 's really is"),
#  (763, "n't our choice ,"),
#  (764, 'we would wish it were others .'),
#  (765, 'Other way other'),
#  (766, 'than it is ,'),
#  (767, 'but'),
#  (768, 'but the point is they keep on doing things'),
#  (769, 'as they are doing around Ukraine at the moment ,'),
#  (770, 'which are intimidatory'),
#  (771, 'and'),
#  (772, 'and not really .'),
#  (773, 'The behavior of the responsible power ,'),
#  (774, 'so you know you have to resist'),
#  (775, 'that as robust'),
#  (776, 'as you can .'),
#  (777, 'Whilst also attempting to engage with with'),
#  (778, 'Moscow'),
#  (779, 'and'),
#  (780, 'and to respect .'),
#  (781, 'That their role in their role as well .'),
#  (782, 'I mean ,'),
#  (783, 'it is not on on this particular issue'),
#  (784, "but I 'm ."),
#  (785, "It 's it 's one of those peculiar things of"),
#  (786, "being doing what I do for a living II've met quite a few"),
#  (787, 'Russians'),
#  (788, 'and I have a huge amount of affection for'),
#  (789, 'them .'),
#  (790, 'There is an element here of .'),
#  (791, 'Which we are trying to do of putting'),
#  (792, 'ourselves in in trying to imagine ?'),
#  (793, 'What is going on in Moscow'),
#  (794, 'because there is'),
#  (795, 'both a pattern of reckless behavior'),
#  (796, 'but is also one looks at his history of'),
#  (797, 'Russia .'),
#  (798, 'You have to accept that .'),
#  (799, 'There is also .'),
#  (800,
#   'They have the ability to misread the international international situation quite badly .'),
#  (801, 'They ,'),
#  (802, 'in their own small circle .'),
#  (803, "They sometimes do n't understand signals"),
#  (804, 'as they should do .'),
#  (805, "That 's"),
#  (806, 'why the clarity is really important to'),
#  (807, 'them'),
#  (808, 'and sometimes they will imagine'),
#  (809, 'that things are going on that simply'),
#  (810, "are n't"),
#  (811, 'so I think again clarity of messaging'),
#  (812, 'and making sure .'),
#  (813, 'That they get that is important .'),
#  (814, 'We also know'),
#  (815,
#   'that Vladimir Putin turns to military interventions acts of nationalism'),
#  (816, "when he 's feeling under pressure ."),
#  (817, "We 've seen"),
#  (818, 'that quite a lot in the past .'),
#  (819, "He 's under pressure now ."),
#  (820, 'Over the Valley .'),
#  (821, 'Protests'),
#  (822,
#   'and that situation do you see this troop buildup on the Ukrainian border .'),
#  (823, 'As an act of weakness .'),
#  (824, "II do n't know what it is ,"),
#  (825, 'but II said earlier on .'),
#  (826, "Tom you 're intrinsically ."),
#  (827, 'Russia is very challenged country .'),
#  (828, 'You know its demographic is not good .'),
#  (829, "It 's economy is not good"),
#  (830, 'and clearly the treatment of Lexan novel nears'),
#  (831, 'as we saw with the .'),
#  (832, 'Thousands of protesters on the streets of well ,'),
#  (833, 'not just Moscow ,'),
#  (834, 'the number of cities shows'),
#  (835, "that there 's a deal of disaffection with with"),
#  (836, 'Mr. Putin'),
#  (837, 'so'),
#  (838, 'but I you know ,'),
#  (839, 'honestly ,'),
#  (840, "I do n't know what ?"),
#  (841, "What 's driving it ,"),
#  (842, "but I do know it 's it"),
#  (843, "'s not welcome"),
#  (844, 'and'),
#  (845, 'and we really need the Russians to deescalate further rush'),
#  (846, 'you mentioned this .'),
#  (847, 'Gru unit that carried out the attack on'),
#  (848, 'Colonel Skripal'),
#  (849, 'and also blew up the check arms factory .'),
#  (850, 'Unit 29155'),
#  (851, "as it 's rather catchy name ."),
#  (852, "It 's safe to say this is a unit quite well"),
#  (853, 'on your radar'),
#  (854, 'and what else do you know about'),
#  (855, "its affection assassination squad is n't it well ?"),
#  (856, 'That is what is there to do'),
#  (857, "and it that 's what it attempted with"),
#  (858, 'Sergei Skripal'),
#  (859, 'and they were involved in this operation in'),
#  (860, 'Czechoslovakia .'),
#  (861, 'So yeah ,'),
#  (862, "we 're very aware of it ."),
#  (863, 'We are very focused on trying to make sure'),
#  (864, 'that they are not able to cause the habit'),
#  (865, 'that they would like to'),
#  (866, "'cause you 've had success in it ,"),
#  (867, 'yeah'),
#  (868, 'look .'),
#  (869, 'I think we ,'),
#  (870, "we did n't wait so after after"),
#  (871, 'Salisbury .'),
#  (872, 'We were able to mobilize a really big international coalition'),
#  (873, 'and a large number of things 160 .'),
#  (874, 'Agents of theirs of the of the Russians .'),
#  (875, 'We kicked out right across the world .'),
#  (876, 'So you know that has a highly disruptive impact'),
#  (877, 'and we will keep after them as long'),
#  (878, 'as they keep doing this sort of things ,'),
#  (879, 'they did in Salisbury Funny ,'),
#  (880, 'China .'),
#  (881, "It 's been sent to me in the past ,"),
#  (882, 'sometimes by people in your former trade'),
#  (883, 'that Russia is a real irritant these days .'),
#  (884, 'But China is the most serious strategic long term threat largely'),
#  (885, 'because China wants the 21st century to'),
#  (886, 'be the Chinese century ,'),
#  (887, 'maybe like the 20th century was the American century .'),
#  (888, 'How big a problem does that pose for'),
#  (889, 'us here in the UK well look'),
#  (890, 'as I said earlier on the people'),
#  (891, 'who run China ?'),
#  (892, "Do n't do n't share our values ."),
#  (893, 'They have a very different value set'),
#  (894, 'and they have a set of interests ,'),
#  (895, 'which collide with ours'),
#  (896, 'and we see that playing out .'),
#  (897, 'Hong Kong being one of particular interest to the UK'),
#  (898, "where what they 've been doing in"),
#  (899, 'Hong Kong is to unravel .'),
#  (900, 'The agreement that they had with the UK'),
#  (901, 'to to run it under a 2 .'),
#  (902, 'Under a system of 2 systems in one country'),
#  (903, 'and'),
#  (904, "that that 's been unraveling"),
#  (905, 'and so .'),
#  (906, 'Quite clearly we have to we have'),
#  (907, 'to respond to those sort of challenges'),
#  (908, 'and we have to also be very clear'),
#  (909, "that we 're going to defend our academic freedom"),
#  (910, "that we 're going to ensure"),
#  (911, 'that the technologies that we develop'),
#  (912, 'and our intellectual property is kept safe'),
#  (913, 'and so we will take measures to .'),
#  (914, 'To try'),
#  (915, 'and ensure'),
#  (916, 'that that is the case ,'),
#  (917, 'but'),
#  (918, 'but at the same time ,'),
#  (919, "I 'll say China is China is"),
#  (920, "it 's a"),
#  (921, "It 's a very complex issue ."),
#  (922, "It 's not a black"),
#  (923, 'and white issue .'),
#  (924, 'You know ,'),
#  (925, 'we want to be able to have a positive relationship with'),
#  (926, 'China .'),
#  (927, "It 's really important to both countries"),
#  (928, 'that we do .'),
#  (929, "Whether it 's trade"),
#  (930, 'or'),
#  (931, "whether it 's particularly climate change"),
#  (932, 'because'),
#  (933, 'if ?'),
#  (934, "If we do n't cooperate with the Chinese then"),
#  (935, 'you are by definition ,'),
#  (936, 'not being out of work with with the country whose economy'),
#  (937, 'will in the next few years become the largest economy in the world'),
#  (938, "and it 's certainly the largest emitter ."),
#  (939, 'So we need to do that .'),
#  (940, "So it 's a"),
#  (941, "It 's a balance as always"),
#  (942, 'and you know my services job .'),
#  (943, 'I guess is to help with the managing of the threat side'),
#  (944, 'and making sure'),
#  (945, 'that we defend'),
#  (946, 'and protect our interests .'),
#  (947, "And it 's"),
#  (948,
#   'if you like a sort of assurance putting assurance wrapper around the positive side'),
#  (949, 'of it .'),
#  (950, 'Climate change is a good example'),
#  (951, 'where you know ,'),
#  (952, 'people sign up to commitments on climate change .'),
#  (953, "And it 's perhaps our job to make sure"),
#  (954, 'that'),
#  (955, 'when people sign up to them'),
#  (956, "that actually what they 're really doing reflects the you know"),
#  (957, "what they 've signed up to MI 6 job"),
#  (958, 'to actually find out'),
#  (959, "whether they 're not admitting you mean"),
#  (960, "but it 's our job is our job"),
#  (961, 'to shine light in places'),
#  (962, 'where people might not want it .'),
#  (963, 'Sean Sean'),
#  (964, 'if you like'),
#  (965, 'and so clearly .'),
#  (966,
#   'We are going to support what is the foremost international foreign policy agenda agenda item'),
#  (967, 'for this country for the planet which'),
#  (968, 'is around the climate emergency'),
#  (969, 'and of course .'),
#  (970, 'We have a role in in that space'),
#  (971, 'would you mean by shining a light in areas'),
#  (972, 'that'),
#  (973, 'when it comes back to this ?'),
#  (974, "Pointed it people it 's it 's a bit like"),
#  (975, "I guess what we 've always done around arms control"),
#  (976, 'is'),
#  (977, 'that you aim to .'),
#  (978, 'Somebody said in a trust'),
#  (979, 'but verify'),
#  (980, 'and I guess in climate change'),
#  (981, 'or anything like that ,'),
#  (982, 'well .'),
#  (983, 'You need everyone to come on board'),
#  (984, 'and to play fair ,'),
#  (985, 'then occasionally just to check to make sure'),
#  (986, 'they are playing fair is a useful thing'),
#  (987, 'to have you have someone ?'),
#  (988, 'Maybe in a field with a ?'),
#  (989, 'Some sort of technical device measuring emission .'),
#  (990, "I 'm I 'm loving the image"),
#  (991, 'Tom'),
#  (992, 'but'),
#  (993, "but I 'm not sure that 's"),
#  (994, "that 's quite what we 're doing OK ."),
#  (995, "I wo n't try"),
#  (996, 'and ask what you are doing is again .'),
#  (997, 'I suspect for a good reason to probably terminal look .'),
#  (998, "You 've been very ,"),
#  (999, 'very good with your time we must wrap up .'),
#  ...]

# %%
frags[1]
# Out:
# [(us, [{'Word': 'us', 'Offset': 17000000, 'Duration': 3700000}]),
#  (today, [{'Word': 'today', 'Offset': 21000000, 'Duration': 5400000}]),
#  (., [])]

# %%
clauses = frags_to_clauses(frags)
[(idx, ' '.join([token.text for (token, offset) in f])) for idx, f in enumerate(clauses)]
# Out:
# [(0, 'Much more thank you very much for joining us today .'),
#  (1, "That 's good to be here ."),
#  (2, 'This is a broadcast first of course ,'),
#  (3, 'the first interview with the serving chief of MI 6'),
#  (4, "and it was n't that long ago"),
#  (5, 'that your name was classified let alone'),
#  (6, 'where you actually work that was also a state secret ,'),
#  (7, 'so I suppose my first question has to be .'),
#  (8, 'What are you doing here in a radio studio doing an interview ?'),
#  (9, "Well , it 's a good question ,"),
#  (10, 'and the secret in the title of'),
#  (11, 'Secret Intelligence Service is going to remain .'),
#  (12, 'There are clearly .'),
#  (13, "Some some things that II wo n't be able to discuss"),
#  (14, 'but over the last 10 years'),
#  (15,
#   'or so my predecessors have gradually tiptoed into into the light a bit'),
#  (16, "and the reason they 've done it and"),
#  (17, "why I 'm keen to ."),
#  (18,
#   'Carry on with it and develop it a bit by coming on to the radio with you today is'),
#  (19, "because I think it 's important"),
#  (20, 'that people understand the role that we play in so far'),
#  (21,
#   'as we can talk about it in keeping people safe on the streets of the UK'),
#  (22, 'and in promoting our interests'),
#  (23, 'and values overseas now you also tweet .'),
#  (24, 'Yeah , in fact ,'),
#  (25, 'you are the first tweeting see'),
#  (26, 'if I can call you'),
#  (27, 'that you do that for what reason again .'),
#  (28, 'You want to be in on the field ,'),
#  (29, 'yeah look .'),
#  (30,
#   "I think it 's it 's for all the same reasons II was on Twitter before I became chief"),
#  (31, 'and I use Twitter ,'),
#  (32, "a lot when I was an ambassador 's ambassador to Turkey ."),
#  (33, 'And I found it a great medium'),
#  (34, 'because you were able to engage with people .'),
#  (35, "It 's not just a broadcast medium ."),
#  (36, 'You have a chance for a bit of back and forth .'),
#  (37, 'I enjoy a bit of banter you get'),
#  (38, 'some you get some pretty toxic stuff .'),
#  (39, 'At one level and you get quite a lot of of humorous stop in Turkey ,'),
#  (40, 'they love conspiracy theories so .'),
#  (41, 'I just found it useful way of bashing back against'),
#  (42, 'some of that stuff ,'),
#  (43, 'and explaining Britain and in this context .'),
#  (44, 'Again , I think it gives me a chance'),
#  (45, 'to engage with people on Twitter talk a bit about the service talk'),
#  (46, "about some of the things we 're trying"),
#  (47, 'to do to modernize the service .'),
#  (48, 'And so you know it was a bit of an experiment ,'),
#  (49, 'but so far , so good I think .'),
#  (50, 'Judging by your turn I used to tweet in Turkish on occasions .'),
#  (51,
#   'I was quite impressive your Turkish Subs pretty pretty good better than mine anyway .'),
#  (52, 'So it is Alright .'),
#  (53, "It 's getting a bit rusty"),
#  (54, 'before we get on to the wider world'),
#  (55, 'and your views on it in your services activities .'),
#  (56, 'As far as you can discuss them .'),
#  (57, 'Of course , let me just ask you about your background .'),
#  (58, 'You spend a bit of time in the diplomatic service ,'),
#  (59, 'you being an ambassador ,'),
#  (60, 'but you were originally an intelligence officer .'),
#  (61, 'You began your career with MI 6 ?'),
#  (62, 'How did you get into the business of espionage ?'),
#  (63, "I 'm absolutely professional intelligence officer ."),
#  (64, 'I really enjoyed my time working as an ambassador'),
#  (65, 'and then working in the Foreign Office'),
#  (66, "but I 've always been an intelligence officer ."),
#  (67, 'To the to the core of my soul'),
#  (68, 'and I think like many folks ,'),
#  (69, 'leaving University looking at careers .'),
#  (70, 'I was looking around .'),
#  (71, 'I was , I did take an interest in journalism'),
#  (72, 'and completely and utterly failed .'),
#  (73, 'I think I applied to the BBC World Service and .'),
#  (74, 'Got rejected without an interview of any kind'),
#  (75, 'so one looks around .'),
#  (76, 'I kept on coming back to the fact'),
#  (77, 'that I wanted to do something overseas .'),
#  (78, 'I want to do something that would make a difference'),
#  (79,
#   'and I was approached so I sort of followed through the application process with with SS'),
#  (80, "and I 've never regretted it ."),
#  (81, "I 've loved every minute of the work"),
#  (82, "that I 've done so with the classic tap on the shoulder"),
#  (83, 'was it at University .'),
#  (84, 'It was at University .'),
#  (85, 'I will even though the gentleman has passed away .'),
#  (86, 'I will respect the confidence of the individual who did it .'),
#  (87, 'But yes , it was very much the way that people read about .'),
#  (88, 'I think he suggested that I might be interested in .'),
#  (89, 'In a parallel career in the parallel field of foreign affair .'),
#  (90, 'I had no idea what he meant'),
#  (91, 'but then I was taking I was asked'),
#  (92, 'to turn up at some building'),
#  (93, 'or the ground building just off of the Mail'),
#  (94, 'and it all became revealed unto me'),
#  (95, 'what I might be getting into'),
#  (96, 'when you finally knew what you were signing up for absolutely'),
#  (97, 'and II did sign up for it .'),
#  (98, 'And and I had a brilliant time there is something about .'),
#  (99, 'Trying to work out who might be prepared'),
#  (100, 'to help us that kind of'),
#  (101, 'if you like a bit of the thrill of the Chase as you try'),
#  (102, 'and sort of find a way in'),
#  (103, 'which you can get alongside them'),
#  (104,
#   'and then the fascinating business of working with people developing relationship'),
#  (105, 'with them having to do .'),
#  (106,
#   'Some pretty wild things you know after dark on the streets of Islamabad .'),
#  (107, "You know it 's the adrenaline is rushing so"),
#  (108, "it 's a very fulfilling ."),
#  (109, "Korea , an you know you 're doing ,"),
#  (110, 'it for a for a genuinely good purpose .'),
#  (111, 'You know you , you know'),
#  (112, "that you 're trying to keep things make things just a bit safer ."),
#  (113, 'To ask you exactly what was you doing on the streets'),
#  (114, 'of his neighborhood after dark ,'),
#  (115, "so I wo n't 'cause I know you would n't tell"),
#  (116, "me I do n't know ,"),
#  (117, "but the service does n't recruit that way anymore ."),
#  (118, "Does it there 's a discrete tap on the shoulder ."),
#  (119, 'In fact , you could even apply openly to join'),
#  (120, "my sense ? Is there 's an invitation on your website"),
#  (121, 'to do that , and understand your recruiting for quite a scene'),
#  (122, 'and you roll .'),
#  (123, 'Externally for the first time I am so I mean ,'),
#  (124, "you 're right of course ."),
#  (125, 'We still take recommendations ,'),
#  (126, 'but clearly we cast on that much more broadly than Oxbridge .'),
#  (127, 'Colleges these days , rightly ,'),
#  (128, 'so and we get people drawing drawing in from all around the UK'),
#  (129, "from all kinds of backgrounds and that 's"),
#  (130, 'as it should be .'),
#  (131, 'Yeah , you apply online .'),
#  (132, 'These days and then we take some care to make sure that .'),
#  (133, 'Once you apply online you can do so safely and'),
#  (134, 'and we can then take the application process forward so'),
#  (135, 'that that works well in for the senior appointments .'),
#  (136,
#   'We quite often advertised and we will shortly be advertising for a role the role'),
#  (137, 'is to be our new Q In Fact .'),
#  (138, "So I 'm quite excited about that ,"),
#  (139, 'about the sort of person we might get to come'),
#  (140, "and join us II'm hoping that will get somebody who ?"),
#  (141,
#   'Probably has gotten industry background who really understands technology at a very deep level'),
#  (142, 'because we need their help .'),
#  (143, 'We are in an increasingly contested difficult world'),
#  (144,
#   'where technology is making what we do for a living more of a challenge .'),
#  (145, 'We have to therefore use and harness technology .'),
#  (146, 'And the only way we can do that .'),
#  (147, 'I think is with good leadership from'),
#  (148,
#   'somebody who can help us partner with the private sector affectively .'),
#  (149, 'So just for people who underwear Q'),
#  (150, 'Exists in James Bond films as the guy'),
#  (151, 'who makes all the gadgets you actually have a real life .'),
#  (152, 'Q We do in the in this one life imitates art .'),
#  (153, 'So we in fact ,'),
#  (154, 'a few years ago .'),
#  (155, 'We were looking to remodel our technical side of it .'),
#  (156, 'A lot of people would would identify the GC'),
#  (157, 'HQ rightly with being this amazing technology organization ,'),
#  (158, 'but my own organization ,'),
#  (159, 'we have a very large technical element to it ,'),
#  (160, 'and many of my colleagues are our technologists .'),
#  (161, 'We were reshaping it .'),
#  (162, 'A few years ago and we can think about the right name for it'),
#  (163, 'and in here we thought walk .'),
#  (164, "Come on let 's go for it and so ,"),
#  (165, 'so we decided to call it Q.'),
#  (166, 'So we have done ever since .'),
#  (167, 'And this will be the leader of that team ,'),
#  (168, 'so the original .'),
#  (169, 'Q was in Flemington Bond'),
#  (170, 'and you borrowed from him .'),
#  (171, "I 'm afraid today ."),
#  (172, "We 've gone the other way around ."),
#  (173, 'You know , see is still see you know ,'),
#  (174, "we 've never gone too ."),
#  (175, 'It was your attention to doing so ,'),
#  (176, 'but yeah , so and I hope that will obviously .'),
#  (177, 'It will excite a bit of interest'),
#  (178,
#   "because it 's it is absolutely critical as the modernization of the servers"),
#  (179,
#   'that we get this partnership around technology right in our traditional model .'),
#  (180, 'Tom has been if you like kind of boffins behind the wire .'),
#  (181, "We 've got fantastic people who Beaver away"),
#  (182, 'and do the most amazing work around .'),
#  (183, 'Developing technology for us ,'),
#  (184, "but in the 21st century that model does n't scale"),
#  (185, "and you ca n't stay ."),
#  (186, "You ca n't achieve the pace you need in order"),
#  (187, 'to stay ahead of your adversaries ,'),
#  (188, 'so the only way to do that'),
#  (189, 'is to be in the mix with technology companies big and small'),
#  (190, 'and that is going to take us into .'),
#  (191, 'I think some interesting and challenging new areas'),
#  (192, "and we 're going to have to"),
#  (193, 'be a little bit more open in terms of that partnering'),
#  (194, 'with with technology companies that we have'),
#  (195, 'been traditionally used to doing that there'),
#  (196, 'will be technology being developed .'),
#  (197, 'Today , Tom where the people developing it .'),
#  (198, 'Will have no idea that there might be an application for'),
#  (199, 'their technology in my world'),
#  (200, 'and so you know ,'),
#  (201, 'I need to reach out to these people'),
#  (202, 'and in order to reach out to them .'),
#  (203, "I 'm going to be ."),
#  (204, "You know , we 're going to be a little bit more open about"),
#  (205, 'who we are .'),
#  (206, "So I think let 's move on to"),
#  (207, 'your actual business end ,'),
#  (208, 'which is your foreign intelligence service .'),
#  (209, 'Domestic intelligence domestically is taken care of by the police ,'),
#  (210, 'etc and your business is international .'),
#  (211,
#   'The Integrative review , which was the big Whitehall wide review of all government foreign policy'),
#  (212,
#   'and security policy published last month painted quite a scary view .'),
#  (213, 'Of the world a world'),
#  (214, "where international sureties ca n't be relied on any longer ."),
#  (215,
#   "International understandings that we 've lived with comfortably maybe"),
#  (216, "since it 's so Cold War may"),
#  (217, 'be going to crumble do you share'),
#  (218, 'that slightly troubling worldview ?'),
#  (219, "I think it 's undoubtedly a highly contested"),
#  (220, 'and in many ways rather dangerous world ?'),
#  (221, 'And I think the integrated review captures that rather well .'),
#  (222, 'I mean , the thing I like about it .'),
#  (223, "It 's not defeatist ,"),
#  (224, 'though it is .'),
#  (225, 'It is and I understand'),
#  (226, 'why you would use to describe it .'),
#  (227, 'In the terms you did ,'),
#  (228, 'but it also sets out a very clear vision of the role'),
#  (229, 'that the UK can play and of course ,'),
#  (230, "we 'll play our part in ."),
#  (231, 'In that because will help along with GC HQ'),
#  (232, 'and MI 5 to defend against those threats .'),
#  (233, 'Wherever they come from ,'),
#  (234, 'but also in our case as SAS one of our jobs .'),
#  (235, "If you 'd like us to provide a kind of assurance wrapper"),
#  (236, 'around some of the more positive forward looking stuff ,'),
#  (237, 'I mean , if you wanna things ,'),
#  (238, 'which is central to ?'),
#  (239, 'The Integrative review as it is a sense of the UK as a science'),
#  (240, 'and technology power uh recognition .'),
#  (241, 'I think that in the 21st century .'),
#  (242, "If you 're going to succeed ,"),
#  (243, 'as a as a country as a nation'),
#  (244, "and you 're going to have to master certain key technologies"),
#  (245, "and certainly you 're going to have"),
#  (246, 'to be in a place where either you'),
#  (247, 'or trusted allies have access to those technologies .'),
#  (248, 'And that if you like please back into what'),
#  (249, 'I was just saying about Q. You know ,'),
#  (250, 'we have got to be absolutely the at the forefront of'),
#  (251, 'that he wants the one single biggest thing'),
#  (252, 'that keeps you awake at night .'),
#  (253, "Now I do n't in all honesty ."),
#  (254, "I sleep well because 'cause There are always issues that one"),
#  (255, 'is concerned about so I think from my perspective .'),
#  (256, 'All of this is ,'),
#  (257, 'is manageable .'),
#  (258, 'As long as we keep doing what some of the stuff'),
#  (259, "that 's in integrated review says we should do ."),
#  (260, 'But mostly the reason ?'),
#  (261, "Why I do n't have sleepless nights in the spaces"),
#  (262, 'because the great advantage .'),
#  (263, 'We have over the authoritarian regimes is'),
#  (264, "they do n't have friends ."),
#  (265, 'Now we have friends ,'),
#  (266, 'we have allies .'),
#  (267, 'And I think you know ,'),
#  (268, "there 's been a bit of a reassertion of"),
#  (269, 'that over the last few months ,'),
#  (270, 'which I think is welcome here in London .'),
#  (271, "So I honestly do n't there are lots of things ."),
#  (272, 'Of course I fret about'),
#  (273, 'and I worry about ,'),
#  (274, 'but but overall , I remain pretty positive about our agenda .'),
#  (275, 'Let me ask him a couple of specifics'),
#  (276, 'that were actually mentioned in the integrated review .'),
#  (277,
#   'One is the prospect of a CBR an attack and the review stated that a CRM ,'),
#  (278, 'which for people who may not know'),
#  (279, 'me as a chemical biological radiological or nuclear attack ,'),
#  (280, 'a dirty bomb .'),
#  (281, "I suppose in Layman 's terms ."),
#  (282,
#   'Being deliverable and being actually quite likely to have happened by 2030 ,'),
#  (283, "is that sort of threat something you 've actively come across"),
#  (284, 'or your officers have come across elsewhere in the world .'),
#  (285, 'It would be stated in those terms .'),
#  (286, "If we had n't ."),
#  (287, "I mean , there 's clear intent from these types of groups"),
#  (288, 'to do us , the maximum amount of harm at the moment .'),
#  (289, 'We have been very successful'),
#  (290, 'if you like I mean ,'),
#  (291, 'one of the one of the truisms about intelligence work .'),
#  (292, 'Thomas that you , you get to see our failures .'),
#  (293, "You do n't get to see our successes"),
#  (294, 'and that is particularly true in true in counterterrorism workwear .'),
#  (295, 'You know , we worked really ,'),
#  (296, 'really hard to the point where awful ,'),
#  (297, "though these attacks are they 've involved pretty low ."),
#  (298, 'Tech use of vehicles or people acquiring knives'),
#  (299, 'and trying to do as much damage as they can ,'),
#  (300, 'but clearly there is there is a limit to'),
#  (301, 'what you can do ,'),
#  (302, 'particularly on brilliant police able to react as fast'),
#  (303, 'as they self evidently do .'),
#  (304, 'So these groups are perpetually looking for something which would'),
#  (305, 'either be what you know what is called in the traders'),
#  (306, 'you know spectacular a 9/11 type thing will find some new'),
#  (307, 'and innovative way of doing it'),
#  (308, "and they 're pretty they innovate they innovate"),
#  (309, 'and their use of social media'),
#  (310, 'and they innovate in trying to do us harm'),
#  (311, "so we 're very conscious of it ."),
#  (312, 'But we take we do a lot of work'),
#  (313, 'to get ahead of that by you know'),
#  (314, 'being able to understand .'),
#  (315, 'These groups and then disrupt them'),
#  (316, 'before they develop the sort of capability'),
#  (317, 'that could do a serious harm have'),
#  (318, 'you come across actual evidence of a real plot no matter ?'),
#  (319, 'How far down the line .'),
#  (320, 'It was obviously an attack directed to the UK'),
#  (321, "II'm not going to get into individual ."),
#  (322, 'Intelligence and what we may not may'),
#  (323, 'or may not have uncovered'),
#  (324, 'but I you know ,'),
#  (325, 'I will say if you like more generally at some'),
#  (326, 'that we have definitely picked up intent from group stock icon .'),
#  (327, 'Al Qaeda and isis in the past to try'),
#  (328, 'and find ways of being'),
#  (329, 'and get hold of this CV RN .'),
#  (330, "Capability and that 's why it 's in there ,"),
#  (331, 'you know it reflects the fact'),
#  (332, "that we know they 're trying ."),
#  (333, 'But so far .'),
#  (334, "We 've managed to stop them from achieving that ."),
#  (335, "We 're not talking about ancient history here"),
#  (336, "we 're talking about active groups now still trying today ."),
#  (337, "Are we , we 're certainly talking about groups ,"),
#  (338, 'which are you know actor .'),
#  (339, 'We all know that Al Qaeda and isis ,'),
#  (340,
#   "although they 've been pretty damaged over the last few years are still there ."),
#  (341, 'You mentioned Irish or isis ,'),
#  (342, 'they go by many names ?'),
#  (343, "They are on the rise again are n't they ?"),
#  (344, 'They were compressive defeated militarily in Syria and Iraq ,'),
#  (345, 'but again another thing .'),
#  (346, 'The IR predicts is that there will be more failed states ,'),
#  (347, 'either in the Middle East or Africa'),
#  (348, 'and we know dash is on the rise in Africa .'),
#  (349, 'Across the continent in this AL West African also East Africa'),
#  (350, 'as we saw in Mozambique .'),
#  (351, 'Quite recently very alarming attack took over town and .'),
#  (352, 'Kill a lot of western workers there'),
#  (353, 'how likely is it at the moment and'),
#  (354,
#   'how close are we seeing another serious somewhere else another failed state that dash'),
#  (355, 'might be able take control of .'),
#  (356, 'Look at some you know ,'),
#  (357, "I wo n't downplay the seriousness of of of the situation ."),
#  (358, 'I mean , one level .'),
#  (359, 'We have been really successful against isis ,'),
#  (360, 'and its main headquarters area in Iraq and Syria'),
#  (361, 'and that pressure remains on them .'),
#  (362, "I do n't think they 've recovered to anything"),
#  (363, 'like you have to think back to where they were ,'),
#  (364, 'and 2014 .'),
#  (365,
#   "Holding swathes of territory they 're just not in that place but they are ,"),
#  (366, 'they are resilient .'),
#  (367, 'We do have to keep the pressure on on the and of course ,'),
#  (368, "we 've been doing that in Afghanistan against"),
#  (369, 'Al Qaeda pretty effectively for the last 20 years .'),
#  (370, 'So we need to find ways of keeping that pressure on them ,'),
#  (371, "but you 're right This is a very toxic ."),
#  (372, 'Creed but one which seems to be able'),
#  (373, 'to use modern social media really effectively'),
#  (374, 'to inspire parallel movements in different parts of the world'),
#  (375, "and what we 're seeing in Mozambique ?"),
#  (376, "Is is pretty disturbing is n't it and you can see"),
#  (377,
#   'where the local authorities are unable to exert appropriate control .'),
#  (378, 'Then the space opens up for these groups'),
#  (379, "and it 's part of my services job ."),
#  (380, 'Of course to try and go to those places shine a light on'),
#  (381, 'some of the stuff going on there'),
#  (382, 'and help to disrupt those groups .'),
#  (383, 'But we can only be part of a broader effort .'),
#  (384, 'I mean , you got ta you got ta back'),
#  (385,
#   'that up with with work in the development space work in conflict prevention and and that is'),
#  (386, 'that you know the duty of of .'),
#  (387, 'Diplomats and others , but'),
#  (388, 'but our role is to try and get in there'),
#  (389, 'and make life as difficult as possible for these groups'),
#  (390, 'and in particular disrupt any efforts by'),
#  (391, 'them to direct tax attacks against the United Kingdom ,'),
#  (392, 'well funny .'),
#  (393, 'You should mention that connections about Afghanistan .'),
#  (394, 'Of course , right chief defense off Johnson .'),
#  (395, 'Carter has expressed his concern and disappointment .'),
#  (396, 'The US pullout militarily from Afghanistan by September ,'),
#  (397,
#   '11th this year , the 20th anniversary of the attacks on the twin towers .'),
#  (398, 'Do you also agree that not having a military presence in'),
#  (399,
#   'Afghanistan any longer makes it harder to disrupt terrorist attacks on the UK Homeland .'),
#  (400, "Look it 's going to force us"),
#  (401, 'to have to work very differently .'),
#  (402, 'You know , we have had a certain model of working'),
#  (403, "as I 've just said"),
#  (404, "as you know it 's been pretty effective against Al Qaeda ."),
#  (405, "We 've been UK supported the peace process ,"),
#  (406, 'and and we continue to do that .'),
#  (407, 'The fact is the president has made his decision'),
#  (408, 'and we have to now work with that .'),
#  (409, "And so we 're doing a lot of work and thinking through"),
#  (410, "how we 're going to achieve the same mission ,"),
#  (411, "but I 'm very clear"),
#  (412, "that there 's been an awful lot of sacrifice clearly ."),
#  (413, "I think it 's 457 servicemen have lost"),
#  (414, 'their lives in the Afghan .'),
#  (415, 'Campaign so we owe it to them to make sure'),
#  (416, "that we preserve some of the gains insecurity that we 've achieved"),
#  (417, 'and we will find a way of doing that ,'),
#  (418, "we 're not going to go anywhere ."),
#  (419, 'We will we will find a way of working'),
#  (420, 'which is in a slightly different model clearly'),
#  (421, "when you do n't have the military on the ground alongside you"),
#  (422, 'but we will find away because .'),
#  (423, "Very clearly we ca n't allow Afghanistan"),
#  (424, 'to slide back to a situation that'),
#  (425, 'we saw in the run up to 9/11 and'),
#  (426, 'that for me is one of those sort of very easy'),
#  (427, 'to state very difficult to execute commitments'),
#  (428, 'that we have no second 9/11 .'),
#  (429, 'So we need to make sure we work with the Americans and others too .'),
#  (430,
#   "Ensure that does n't happen with your input into it your advice if your counterpart ,"),
#  (431, 'the director of the CIA for example ,'),
#  (432, 'to do just that to stay in Afghanistan .'),
#  (433, 'Military is that what you wanted to see happen ,'),
#  (434, "but I probably wo n't go into the sort of conversations ."),
#  (435, 'I would have as a director of CIA'),
#  (436, 'because otherwise I might not have very many of them so .'),
#  (437, 'Look we , we work incredibly closely with our American partners'),
#  (438, 'and they are as focused'),
#  (439, 'as we are on trying to make sure'),
#  (440,
#   "that that threat does n't re emerge from from Afghanistan so you know"),
#  (441, "that that 's what we 'll do"),
#  (442, "we 'll work together on it ,"),
#  (443, 'but the world is going to be ?'),
#  (444, "Let 's say because of the US pullout ."),
#  (445, "I think it 's it 's difficult to judge ."),
#  (446, 'We will have to see what happens ,'),
#  (447, 'but I think you know in my business .'),
#  (448, 'You know you , you plan for the worst'),
#  (449, 'and so you work through the scenarios'),
#  (450, 'that you need to ,'),
#  (451, "but I 'm really clear"),
#  (452, "that there 's a job to be done continuing job"),
#  (453, 'to be done in Afghanistan'),
#  (454, 'and we will have to find a way to do it .'),
#  (455, "Let 's talk about Russia ."),
#  (456,
#   'There are currently 100 thousand Russian troops on the Ukraine border'),
#  (457, 'President Putin this week is also vowed to'),
#  (458, 'and I quote make his enemies sorry as never before'),
#  (459, 'if they crosses red lines do you believe an invasion ?'),
#  (460, 'Is imminent Russia into Ukraine was this'),
#  (461, 'is some form of Saber rattling ?'),
#  (462, "Look , I do n't think it 's entirely clear"),
#  (463, "what is in Mr. Putin 's mind and it may be"),
#  (464, "that he 's not made up his mind yet quite"),
#  (465, 'what he wants to do ,'),
#  (466, "but clearly what they 've been doing around the borders of"),
#  (467, "Ukraine is deeply worrying 'cause"),
#  (468, 'as you rightly say Tom This is the biggest build up since .'),
#  (469, "the Cold War It 's larger than in 2014 ,"),
#  (470, 'when they ? Invaded and annexed Crimea'),
#  (471, 'so all we can do at this point'),
#  (472, 'is to signal really clearly to Moscow that'),
#  (473, 'if they you know where our own .'),
#  (474, 'It would be very clear in our messaging'),
#  (475, 'that he would pay a huge price if he did ,'),
#  (476, "and he 's still paying the Russian people"),
#  (477, 'are still suffering from the sanctions that Putin brought'),
#  (478, 'upon them in 2014 .'),
#  (479, 'So I hope that you know'),
#  (480, "that he 's not intending anything of that kind but it 's ."),
#  (481, 'It is very worrying and the problem with the Russians'),
#  (482, "as we 've experienced here in Salisbury ,"),
#  (483,
#   'about which dice and I still get I still get angry in that sorry because I know .'),
#  (484,
#   'How near we came to very significant casualties you know if you imagine ?'),
#  (485,
#   'What would have happened if a kid come across that material and spread around'),
#  (486, 'and the family of .'),
#  (487, 'Dawn Sturgess of course ,'),
#  (488, "you know , I 've had an awful tragedy visited"),
#  (489, 'upon them when when she was killed by it .'),
#  (490, 'So there is this sort of .'),
#  (491,
#   'There is this element of recklessness there in the way they go about things'),
#  (492, "and we 've just had this extraordinary story and in Czechoslovakia ."),
#  (493, "I mean , it 's extraordinary"),
#  (494, "if you think about it 's the same groups ,"),
#  (495, 'the same group and Russian military intelligence Gru .'),
#  (496,
#   'Same 2 individuals who came to Salisbury involved in an attack on a factory ,'),
#  (497, 'which left 2 checks dead so .'),
#  (498, 'When you get that pattern of reckless behavior of course ,'),
#  (499,
#   "you then look at what 's happening around Ukraine and and of course ,"),
#  (500, "it gives us worries us and it 's"),
#  (501, "why we 've coordinated so closely with"),
#  (502, "our allies to make sure we 're getting"),
#  (503, 'her messages back to President Putin'),
#  (504, 'and have those firm messages being passed .'),
#  (505, 'I mean , you can make politicians can make speeches'),
#  (506, 'but it did .'),
#  (507, 'Are you communicating ? Over other channels to make sure'),
#  (508, 'that the message is received ,'),
#  (509,
#   'loud and clear that there will be some sort of recompense at the Russians'),
#  (510, 'are in absolutely no doubt of'),
#  (511, 'where the UK stands on this issue and there'),
#  (512,
#   'and absolutely no doubt aware the Biden administration stands on this issue'),
#  (513, 'because the channels are open .'),
#  (514, 'I mean , they they told me I wonder who'),
#  (515, "'s actually picked up the phone ."),
#  (516, 'Have you I have not picked up the phone but'),
#  (517, 'but I you know I have ways of communicating what ?'),
#  (518, 'What I need to do .'),
#  (519, 'But there are plenty of other channels'),
#  (520, 'and we sit next to them in the UN'),
#  (521, 'Security Council as permanent permanent members'),
#  (522, 'and we are able to communicate with them .'),
#  (523, "It 's not you know ,"),
#  (524, 'we , we want to this is not .'),
#  (525, 'At the end of the day ,'),
#  (526, 'the the sort of relationship .'),
#  (527, 'We want to have with the Russians .'),
#  (528, "It 's really it 's really is n't our choice ,"),
#  (529, 'we would wish it were others .'),
#  (530, 'Other way other than it is ,'),
#  (531, 'but but the point is they keep on doing things'),
#  (532, 'as they are doing around Ukraine at the moment ,'),
#  (533, 'which are intimidatory and and not really .'),
#  (534, 'The behavior of the responsible power ,'),
#  (535, 'so you know you have to resist that as robust as you can .'),
#  (536,
#   'Whilst also attempting to engage with with Moscow and and to respect .'),
#  (537, 'That their role in their role as well .'),
#  (538, 'I mean , it is not on on this particular issue'),
#  (539, "but I 'm ."),
#  (540, "It 's it 's one of those peculiar things of"),
#  (541, "being doing what I do for a living II've met quite a few Russians"),
#  (542, 'and I have a huge amount of affection for them .'),
#  (543, 'There is an element here of .'),
#  (544, 'Which we are trying to do of putting'),
#  (545, 'ourselves in in trying to imagine ?'),
#  (546, 'What is going on in Moscow because there is'),
#  (547, 'both a pattern of reckless behavior'),
#  (548, 'but is also one looks at his history of Russia .'),
#  (549, 'You have to accept that .'),
#  (550, 'There is also .'),
#  (551,
#   'They have the ability to misread the international international situation quite badly .'),
#  (552, 'They , in their own small circle .'),
#  (553, "They sometimes do n't understand signals"),
#  (554, 'as they should do .'),
#  (555, "That 's why the clarity is really important to them"),
#  (556, 'and sometimes they will imagine'),
#  (557, "that things are going on that simply are n't"),
#  (558, 'so I think again clarity of messaging and making sure .'),
#  (559, 'That they get that is important .'),
#  (560,
#   'We also know that Vladimir Putin turns to military interventions acts of nationalism'),
#  (561, "when he 's feeling under pressure ."),
#  (562, "We 've seen that quite a lot in the past ."),
#  (563, "He 's under pressure now ."),
#  (564, 'Over the Valley .'),
#  (565,
#   'Protests and that situation do you see this troop buildup on the Ukrainian border .'),
#  (566, 'As an act of weakness .'),
#  (567, "II do n't know what it is ,"),
#  (568, 'but II said earlier on .'),
#  (569, "Tom you 're intrinsically ."),
#  (570, 'Russia is very challenged country .'),
#  (571, 'You know its demographic is not good .'),
#  (572, "It 's economy is not good"),
#  (573, 'and clearly the treatment of Lexan novel nears'),
#  (574, 'as we saw with the .'),
#  (575, 'Thousands of protesters on the streets of well ,'),
#  (576, 'not just Moscow , the number of cities shows'),
#  (577, "that there 's a deal of disaffection with with Mr. Putin so"),
#  (578, 'but I you know ,'),
#  (579, "honestly , I do n't know what ?"),
#  (580, "What 's driving it ,"),
#  (581, "but I do know it 's it 's not welcome and"),
#  (582,
#   'and we really need the Russians to deescalate further rush you mentioned this .'),
#  (583, 'Gru unit that carried out the attack on Colonel Skripal'),
#  (584, 'and also blew up the check arms factory .'),
#  (585, "Unit 29155 as it 's rather catchy name ."),
#  (586, "It 's safe to say this is a unit quite well on your radar"),
#  (587, 'and what else do you know about'),
#  (588, "its affection assassination squad is n't it well ?"),
#  (589, 'That is what is there to do'),
#  (590, "and it that 's what it attempted with Sergei Skripal"),
#  (591, 'and they were involved in this operation in Czechoslovakia .'),
#  (592, "So yeah , we 're very aware of it ."),
#  (593, 'We are very focused on trying to make sure'),
#  (594, 'that they are not able to cause the habit'),
#  (595, 'that they would like to'),
#  (596, "'cause you 've had success in it ,"),
#  (597, 'yeah look .'),
#  (598, "I think we , we did n't wait so after after"),
#  (599, 'Salisbury .'),
#  (600, 'We were able to mobilize a really big international coalition'),
#  (601, 'and a large number of things 160 .'),
#  (602, 'Agents of theirs of the of the Russians .'),
#  (603, 'We kicked out right across the world .'),
#  (604, 'So you know that has a highly disruptive impact'),
#  (605, 'and we will keep after them as long'),
#  (606, 'as they keep doing this sort of things ,'),
#  (607, 'they did in Salisbury Funny ,'),
#  (608, 'China .'),
#  (609, "It 's been sent to me in the past ,"),
#  (610, 'sometimes by people in your former trade'),
#  (611, 'that Russia is a real irritant these days .'),
#  (612, 'But China is the most serious strategic long term threat largely'),
#  (613, 'because China wants the 21st century to'),
#  (614, 'be the Chinese century ,'),
#  (615, 'maybe like the 20th century was the American century .'),
#  (616, 'How big a problem does that pose for'),
#  (617, 'us here in the UK well look'),
#  (618, 'as I said earlier on the people who run China ?'),
#  (619, "Do n't do n't share our values ."),
#  (620, 'They have a very different value set'),
#  (621, 'and they have a set of interests ,'),
#  (622, 'which collide with ours and we see that playing out .'),
#  (623, 'Hong Kong being one of particular interest to the UK'),
#  (624, "where what they 've been doing in"),
#  (625, 'Hong Kong is to unravel .'),
#  (626, 'The agreement that they had with the UK'),
#  (627, 'to to run it under a 2 .'),
#  (628, 'Under a system of 2 systems in one country and'),
#  (629, "that that 's been unraveling and so ."),
#  (630, 'Quite clearly we have to we have'),
#  (631, 'to respond to those sort of challenges'),
#  (632, 'and we have to also be very clear'),
#  (633, "that we 're going to defend our academic freedom"),
#  (634, "that we 're going to ensure"),
#  (635, 'that the technologies that we develop'),
#  (636, 'and our intellectual property is kept safe'),
#  (637, 'and so we will take measures to .'),
#  (638, 'To try and ensure that that is the case ,'),
#  (639, 'but but at the same time ,'),
#  (640, "I 'll say China is China is it 's a"),
#  (641, "It 's a very complex issue ."),
#  (642, "It 's not a black and white issue ."),
#  (643, 'You know , we want to be able to have a positive relationship with'),
#  (644, 'China .'),
#  (645, "It 's really important to both countries that we do ."),
#  (646, "Whether it 's trade or"),
#  (647, "whether it 's particularly climate change because if ?"),
#  (648, "If we do n't cooperate with the Chinese then"),
#  (649, 'you are by definition ,'),
#  (650, 'not being out of work with with the country whose economy'),
#  (651, 'will in the next few years become the largest economy in the world'),
#  (652, "and it 's certainly the largest emitter ."),
#  (653, 'So we need to do that .'),
#  (654, "So it 's a It 's a balance as always"),
#  (655, 'and you know my services job .'),
#  (656,
#   'I guess is to help with the managing of the threat side and making sure that we defend'),
#  (657, 'and protect our interests .'),
#  (658,
#   "And it 's if you like a sort of assurance putting assurance wrapper around the positive side of it ."),
#  (659, 'Climate change is a good example where you know ,'),
#  (660, 'people sign up to commitments on climate change .'),
#  (661, "And it 's perhaps our job to make sure that"),
#  (662, 'when people sign up to them'),
#  (663, "that actually what they 're really doing reflects the you know"),
#  (664, "what they 've signed up to MI 6 job to actually find out"),
#  (665, "whether they 're not admitting you mean"),
#  (666, "but it 's our job is our job"),
#  (667, 'to shine light in places'),
#  (668, 'where people might not want it .'),
#  (669, 'Sean Sean if you like and so clearly .'),
#  (670,
#   'We are going to support what is the foremost international foreign policy agenda agenda item'),
#  (671, 'for this country for the planet which'),
#  (672, 'is around the climate emergency and of course .'),
#  (673, 'We have a role in in that space'),
#  (674, 'would you mean by shining a light in areas that'),
#  (675, 'when it comes back to this ?'),
#  (676, "Pointed it people it 's it 's a bit like"),
#  (677, "I guess what we 've always done around arms control is"),
#  (678, 'that you aim to .'),
#  (679, 'Somebody said in a trust but verify'),
#  (680, 'and I guess in climate change'),
#  (681, 'or anything like that ,'),
#  (682, 'well .'),
#  (683, 'You need everyone to come on board'),
#  (684, 'and to play fair ,'),
#  (685, 'then occasionally just to check to make sure'),
#  (686, 'they are playing fair is a useful thing'),
#  (687, 'to have you have someone ?'),
#  (688, 'Maybe in a field with a ?'),
#  (689, 'Some sort of technical device measuring emission .'),
#  (690, "I 'm I 'm loving the image Tom but"),
#  (691, "but I 'm not sure that 's"),
#  (692, "that 's quite what we 're doing OK ."),
#  (693, "I wo n't try and ask what you are doing is again ."),
#  (694, 'I suspect for a good reason to probably terminal look .'),
#  (695, "You 've been very ,"),
#  (696, 'very good with your time we must wrap up .'),
#  (697, 'But I have to ask you fine at least'),
#  (698, "'cause My 11 year old son has"),
#  (699, 'been bugging me about this more to me .'),
#  (700, 'To ask you have you seen the new'),
#  (701, 'James Bond film yet .'),
#  (702, 'No one else in the world appears to have'),
#  (703, 'and is there any way you can organize some sort of screening'),
#  (704, 'for your staff that you could perhaps invite me too .'),
#  (705, 'I have not seen it .'),
#  (706, "I 'm really looking forward to it ."),
#  (707, 'You know , we talked about with the with Bon'),
#  (708, 'Bon is a double edged thing for us ,'),
#  (709, 'but you know it .'),
#  (710, "Miss capable and I 'm very much looking forward to the next film ."),
#  (711, 'I loved I mean .'),
#  (712, "I love the films it does n't bear any much relation"),
#  (713, 'to the reality of what we do owe you know bits bits and pieces .'),
#  (714, 'But we talked about .'),
#  (715, 'Q earlier on .'),
#  (716, 'There are certain elements echoes sometimes of that ,'),
#  (717, "but no we James Bond is wonderfully insubordinate to M. Is n't it ?"),
#  (718, 'I you know ? I feel'),
#  (719, "that that does n't go on in my in service ?"),
#  (720, 'Do you ever moneypenny ?'),
#  (721, 'Anne .'),
#  (722, 'I think that my wonderful private office .'),
#  (723, "I 'm not entirely sure"),
#  (724, "how they 've reacted being described as Moneypenny"),
#  (725, 'as they did with this week .'),
#  (726, "Rob 's number 5 Ken McCallum said"),
#  (727, 'it was time to cast off the martini drinking stereotypes of spies'),
#  (728, 'and what is the world coming to ,'),
#  (729, "if you ca n't have a vodka martini shaken not stirred anymore ."),
#  (730, 'Well , they go .'),
#  (731, 'They go there .'),
#  (732, "There is II'm not sure MI 5"),
#  (733,
#   'is entitled to start taking away James Bond from us and martini drinking .'),
#  (734, 'All that , but but'),
#  (735, "but I 'll let Ken off on this occasion ."),
#  (736, 'Rich , Moore .'),
#  (737, 'Thank you so much for talking to'),
#  (738, 'us on June T this morning have been very ,'),
#  (739, 'very interesting .'),
#  (740, 'Indeed , thank you very much .')]

# %%
captions = clauses_to_captions(clauses)
list(captions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /workspaces/stt/app/src/displacy.ipynb Cell 14' in <cell line: 2>()
#       <a href='vscode-notebook-cell://dev-container%2B5c5c77736c2e6c6f63616c686f73745c5562756e74755c686f6d655c6d6f73735c636f64655c737474/workspaces/stt/app/src/displacy.ipynb#ch0000013vscode-remote?line=0'>1</a> captions = clauses_to_captions(clauses)
# ----> <a href='vscode-notebook-cell://dev-container%2B5c5c77736c2e6c6f63616c686f73745c5562756e74755c686f6d655c6d6f73735c636f64655c737474/workspaces/stt/app/src/displacy.ipynb#ch0000013vscode-remote?line=1'>2</a> list(captions)
#
# /workspaces/stt/app/src/displacy.ipynb Cell 10' in clauses_to_captions(clauses)
#       <a href='vscode-notebook-cell://dev-container%2B5c5c77736c2e6c6f63616c686f73745c5562756e74755c686f6d655c6d6f73735c636f64655c737474/workspaces/stt/app/src/displacy.ipynb#ch0000009vscode-remote?line=0'>1</a> def clauses_to_captions(clauses: list):
#       <a href='vscode-notebook-cell://dev-container%2B5c5c77736c2e6c6f63616c686f73745c5562756e74755c686f6d655c6d6f73735c636f64655c737474/workspaces/stt/app/src/displacy.ipynb#ch0000009vscode-remote?line=1'>2</a>     for c in clauses:
# ----> <a href='vscode-notebook-cell://dev-container%2B5c5c77736c2e6c6f63616c686f73745c5562756e74755c686f6d655c6d6f73735c636f64655c737474/workspaces/stt/app/src/displacy.ipynb#ch0000009vscode-remote?line=2'>3</a>         caption_nlp = nlp([t for (t,o) in c])
#       <a href='vscode-notebook-cell://dev-container%2B5c5c77736c2e6c6f63616c686f73745c5562756e74755c686f6d655c6d6f73735c636f64655c737474/workspaces/stt/app/src/displacy.ipynb#ch0000009vscode-remote?line=3'>4</a>         caption_text = caption_nlp.text
#       <a href='vscode-notebook-cell://dev-container%2B5c5c77736c2e6c6f63616c686f73745c5562756e74755c686f6d655c6d6f73735c636f64655c737474/workspaces/stt/app/src/displacy.ipynb#ch0000009vscode-remote?line=4'>5</a>         caption_start = c[0][1]['Offset']
#
# File ~/.venv/lib64/python3.9/site-packages/spacy/language.py:1005, in Language.__call__(self, text, disable, component_cfg)
#     <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=983'>984</a> def __call__(
#     <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=984'>985</a>     self,
#     <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=985'>986</a>     text: Union[str, Doc],
#    (...)
#     <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=988'>989</a>     component_cfg: Optional[Dict[str, Dict[str, Any]]] = None,
#     <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=989'>990</a> ) -> Doc:
#     <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=990'>991</a>     """Apply the pipeline to some text. The text can span multiple sentences,
#     <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=991'>992</a>     and can contain arbitrary whitespace. Alignment into the original string
#     <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=992'>993</a>     is preserved.
#    (...)
#    <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=1002'>1003</a>     DOCS: https://spacy.io/api/language#call
#    <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=1003'>1004</a>     """
# -> <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=1004'>1005</a>     doc = self._ensure_doc(text)
#    <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=1005'>1006</a>     if component_cfg is None:
#    <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=1006'>1007</a>         component_cfg = {}
#
# File ~/.venv/lib64/python3.9/site-packages/spacy/language.py:1096, in Language._ensure_doc(self, doc_like)
#    <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=1093'>1094</a> if isinstance(doc_like, str):
#    <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=1094'>1095</a>     return self.make_doc(doc_like)
# -> <a href='file:///home/vscode/.venv/lib64/python3.9/site-packages/spacy/language.py?line=1095'>1096</a> raise ValueError(Errors.E866.format(type=type(doc_like)))
#
# ValueError: [E866] Expected a string or 'Doc' as input, but got: <class 'list'>.

# %%
clause = ' '.join([t.text for (t,o) in frags[17] + frags[18]])
clause_doc = nlp(clause)
displacy.serve(clause_doc, style='dep', options = { 'compact': True, 'jupyter': True })#
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e34379b3fc6b4e748cb509d31dd61422-0" class="displacy" width="2900" height="737.0" direction="ltr" style="max-width: none; height: 737.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">last</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">10</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">years</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">so</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">predecessors</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">have</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">gradually</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">tiptoed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">into</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">light</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">bit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e34379b3fc6b4e748cb509d31dd61422-0-0" stroke-width="2px" d="M62,602.0 62,402.0 1850.0,402.0 1850.0,602.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e34379b3fc6b4e748cb509d31dd61422-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,604.0 L58,596.0 66,596.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e34379b3fc6b4e748cb509d31dd61422-0-1" stroke-width="2px" d="M212,602.0 212,427.0 1847.0,427.0 1847.0,602.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e34379b3fc6b4e748cb509d31dd61422-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,604.0 L208,596.0 216,596.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e34379b3fc6b4e748cb509d31dd61422-0-2" stroke-width="2px" d="M362,602.0 362,527.0 785.0,527.0 785.0,602.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e34379b3fc6b4e748cb509d31dd61422-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M362,604.0 L358,596.0 366,596.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e34379b3fc6b4e748cb509d31dd61422-0-3" stroke-width="2px" d="M512,602.0 512,552.0 782.0,552.0 782.0,602.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e34379b3fc6b4e748cb509d31dd61422-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,604.0 L508,596.0 516,596.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-e34379b3fc6b4e748cb509d31dd61422-0-4" stroke-width="2px" d="M662,602.0 662,577.0 779.0,577.0 779.0,602.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-e34
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
long_clauses = [f for f in frags if len(f) > 14]
len(long_clauses)
# Out:
# 1

# %%
clause = ' '.join([t.text for (t,o) in long_clauses[0]])
clause_doc = nlp(clause)
displacy.serve(clause_doc, style='dep', options = { 'compact': True, 'jupyter': True })#
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6d4ddcfa7a78463cbc4bd6008580b12f-0" class="displacy" width="2300" height="587.0" direction="ltr" style="max-width: none; height: 587.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">going</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">support</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">foremost</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">international</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">foreign</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">policy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">agenda</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">agenda</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">item</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6d4ddcfa7a78463cbc4bd6008580b12f-0-0" stroke-width="2px" d="M62,452.0 62,402.0 338.0,402.0 338.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6d4ddcfa7a78463cbc4bd6008580b12f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,454.0 L58,446.0 66,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6d4ddcfa7a78463cbc4bd6008580b12f-0-1" stroke-width="2px" d="M212,452.0 212,427.0 335.0,427.0 335.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6d4ddcfa7a78463cbc4bd6008580b12f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,454.0 L208,446.0 216,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6d4ddcfa7a78463cbc4bd6008580b12f-0-2" stroke-width="2px" d="M512,452.0 512,427.0 635.0,427.0 635.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6d4ddcfa7a78463cbc4bd6008580b12f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,454.0 L508,446.0 516,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6d4ddcfa7a78463cbc4bd6008580b12f-0-3" stroke-width="2px" d="M362,452.0 362,402.0 638.0,402.0 638.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6d4ddcfa7a78463cbc4bd6008580b12f-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M638.0,454.0 L642.0,446.0 634.0,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6d4ddcfa7a78463cbc4bd6008580b12f-0-4" stroke-width="2px" d="M812,452.0 812,427.0 935.0,427.0 935.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6d4ddcfa7a78463cbc4bd6008580b12f-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M812,454.0 L808,446.0 816,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6d4ddcfa7a78463cbc4bd6008580b12f-0-5" stroke-width="2px" d="M662,452.0 662,402.0 938.0,402.0 938.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6d4ddcfa7a78463cbc4bd6008580b12f-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M938.0,454.0 L942.0,446.0 934.0,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6d4ddcfa7a78463cbc4bd6008580b12f-0-6" stroke-width="2px" d
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
clause = ' '.join([t.text for (t,o) in long_clauses[0]])
clause_doc = nlp(clause)
displacy.serve(clause_doc, style='dep', options = { 'compact': True, 'jupyter': True })#
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="c728165831cb41988b2c51d3f781645f-0" class="displacy" width="3200" height="662.0" direction="ltr" style="max-width: none; height: 662.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">We</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">going</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">support</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">what</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">foremost</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">international</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">foreign</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">policy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">agenda</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">agenda</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">item</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">country</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="572.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">planet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c728165831cb41988b2c51d3f781645f-0-0" stroke-width="2px" d="M62,527.0 62,477.0 335.0,477.0 335.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c728165831cb41988b2c51d3f781645f-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,529.0 L58,521.0 66,521.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c728165831cb41988b2c51d3f781645f-0-1" stroke-width="2px" d="M212,527.0 212,502.0 332.0,502.0 332.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c728165831cb41988b2c51d3f781645f-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,529.0 L208,521.0 216,521.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c728165831cb41988b2c51d3f781645f-0-2" stroke-width="2px" d="M512,527.0 512,502.0 632.0,502.0 632.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c728165831cb41988b2c51d3f781645f-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M512,529.0 L508,521.0 516,521.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-c728165831cb41988b2c51d3f781645f-0-3" stroke-width="2px" d="M362,527.0 362,477.0 635.0,477.0 635.0,527.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-c728165831cb41988b2c51d3f781645f-0-3" class="displacy-label" startOffs
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %%
clause = ' '.join([t.text for (t,o) in long_clauses[0]])
clause_doc = nlp(clause)
displacy.serve(clause_doc, style='dep', options = { 'compact': True, 'jupyter': True })#
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="dad3ac0a334a4febb6f6617d789d53cc-0" class="displacy" width="3800" height="587.0" direction="ltr" style="max-width: none; height: 587.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">because</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">it</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">absolutely</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">critical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">modernization</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">servers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">get</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">partnership</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">around</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">technology</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">right</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">our</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">traditional</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="497.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">model .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dad3ac0a334a4febb6f6617d789d53cc-0-0" stroke-width="2px" d="M62,452.0 62,402.0 338.0,402.0 338.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dad3ac0a334a4febb6f6617d789d53cc-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,454.0 L58,446.0 66,446.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-dad3ac0a334a4febb6f6617d789d53cc-0-1" stroke-width="2px" d="M212,452.0 212,427.0 335.0,427.0 335.0,452.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-dad3ac0a334a4febb6f6617d789d53cc-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M212,454.0 L208,446.0
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.
